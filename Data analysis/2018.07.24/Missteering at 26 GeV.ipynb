# %% [markdown]
# # Missteering measurement at 26 GeV
#
# Measurement at 26 GeV firing again KFA45 at the second injection instance. Any kick possible from 60 kV on

# %%
# %run /eos/project/l/liu/Toolbox/myToolbox.py
print '---'
# %run /eos/user/e/esenes/PS-analysis-tools/eTools.py
print '---'
sys.path.append('/eos/project/l/liu/Instrumentation/Scripts')
import metaclass
# Out:
# Version 0.03. This is the latest version.
# Please help me to improve it reporting bugs to guido.sterbini@cern.ch.
# Your platform is Linux-3.10.0-693.21.1.el7.x86_64-x86_64-with-redhat-6.9-Carbon
# Your folder is /eos/user/e/esenes/PS-injection-steering/Data analysis/2018.07.24
# Your IP is 172.17.0.19
# 2018-08-14 14:27:10
# ---
# Version 0.1
# Use at your own risk. Please report bugs to eugenio.senes@cern.ch
# Fork it at https://gitlab.cern.ch/esenes/PS-analysis-tools
# ---

# %%
sys.path.append('/eos/project/l/liu/Instrumentation/Scripts')
import metaclass

# %% [markdown]
# # User inputs

# %%
folderPath = '/eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.07.24'

matlabVars = ['PR_BWS_65_H_ROT.Acquisition.value.projDataSet1', # Wirescanner 65
                'PR_BWS_65_H_ROT.Acquisition.value.projPositionSet1',
                'PR_BWS_65_H_ROT.Acquisition.value.acqTimeInCycleSet1',
                'PR_BWS_85_V_ROT.Acquisition.value.projDataSet1', # Wirescanner 85
                'PR_BWS_85_V_ROT.Acquisition.value.projPositionSet1',
                'PR_BWS_85_V_ROT.Acquisition.value.acqTimeInCycleSet1',
                'PI2_KFA45.AQN1.value',
                'PI2_KFA45.CCV.value', 
                'logical_PI_KFA45.K.value', # Kicker k parameter value (mrad)
                'PR_BPM.AcquisitionOrbit.value.position', # BPMs
                'PR_BPM.AcquisitionTrajectoryBBB.value.position',
                'PR_BPM.AcquisitionTrajectoryBBB.value.channelNames',
                'PR_BCT_ST.Samples.value.samples']

# %%
# let's start with the matlab data
files = sorted(glob.glob(folderPath+'/missteering/data_steering/2018*.mat'))
print 'Found ' + str(len(files)) + ' data files'
# Out:
# Found 85 data files

# %%
myDataFrame = myToolbox.fromMatlabToDataFrame(files,matlabVars,verbose=False)

# %%
# set the kicker voltage to zero when the kicker is off
myDataFrame['PI2_KFA45.CCV.value'].loc[myDataFrame['PI2_KFA45.AQN1.value'] == 0.] = 0.
# Out:
# /cvmfs/sft.cern.ch/lcg/views/LCG_93/x86_64-slc6-gcc62-opt/lib/python2.7/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# # Data cleanup

# %%
myDataFrame = checkDuplicates(myDataFrame) # Drop double acquisitions from matlab
myDataFrame = checkBPMData(myDataFrame) # BPMs fault
# manual data drop
# myDataFrame = myDataFrame.drop(myDataFrame.loc['2017-11-14 17:58:45.100000'].name) # X wirescanner fault
# myDataFrame = myDataFrame.drop(myDataFrame.loc['2017-11-14 17:59:28.300000'].name) # non-phys emittance
# Out:
# Dropped 1 duplicate(s)
# ---
# BPM data ok
# ---

# %% [markdown]
# # Import the optics model

# %%
# get the optics functions from the model
optics = metaclass.twiss('/eos/user/e/esenes/PS-injection-steering/MADx/PS_twiss_files/ps_6.21_6.185.twiss')
# Out:
# Problem parsing: @ ORBIT_-CT        %le                  -0
#
# Going to be parsed as string
# Problem persits, let's ignore it!

# %% [markdown]
# # Booster emittance

# %%
# emix_norm_PSB = 2.484
# emiy_norm_PSB = 2.076

# emix_geom_PSB = emix_norm_PSB/(betar*gammar)
# emiy_geom_PSB = emiy_norm_PSB/(betar*gammar)

# %% [markdown]
# # Match the tomogram data

# %%
# directly copied from one of Guido's analyses
def extractProfile(fileName):
    '''Give me the input file (.dat) of the tomogram and I will give you 2 output:
        the deltaP_P and the the momentum distribution profile.
    ''' 

    print('/eos/project/l/liu/Instrumentation/tomography/runofflinetomo ' + fileName)
    a=os.system('/eos/project/l/liu/Instrumentation/tomography/runofflinetomo ' + fileName)
    
    convergence=np.loadtxt(fileName[0:-4] + '/d001.data')
    image=np.loadtxt(fileName[0:-4] + '/image001.data')
    with open(fileName[0:-4] + '/input_v2.dat','r') as stream: tomofileheader = stream.readlines()[:98]

    myInput={'PLSUSER': tomofileheader[0][0:-1],
            'NumberOfframes': np.int(tomofileheader[16][0:-1]),
            'B_T': np.double(tomofileheader[75][0:-1]),
            'Bdot_T_per_s': np.double(tomofileheader[77][0:-1]),
            'machineRadius_m': np.double(tomofileheader[79][0:-1]),
            'bendingRadius_m': np.double(tomofileheader[81][0:-1]),
            'particleMass_eV': np.double(tomofileheader[85][0:-1]),
            'h': np.int(np.double(tomofileheader[69][0:-1])),
            'ctime': np.int(tomofileheader[2]),
            'cycleStamp':np.int(tomofileheader[1]),                    # cyclestamp in unix time
            'pickupSensitivity':np.double(tomofileheader[97])          # pickup sensitivity
    }

    with open(fileName[0:-4] + '/plotinfo.data','r') as stream: tomofileheader = stream.readlines()

    myInput['profilecount']=np.int(str.split(tomofileheader[1])[2])
    myInput['profilelength']=np.int(str.split(tomofileheader[3])[2])

    myInput['dtbin']=np.double(str.split(tomofileheader[5])[2])
    myInput['dEbin']=np.double(str.split(tomofileheader[7])[2])
    myInput['xat0']=np.double(str.split(tomofileheader[11])[2])
    myInput['yat0']=np.double(str.split(tomofileheader[12])[2])
    myInput['eperimage']=np.double(str.split(tomofileheader[9])[2])

    mySpeedOfLight=299792458. #TODO
    myInput['momentum_eV']=myInput['B_T']*myInput['bendingRadius_m']/(10/mySpeedOfLight*1e8)*1.e9 #TODO
    myInput['totalEnergy_eV']=np.sqrt(myInput['momentum_eV']**2+myInput['particleMass_eV']**2)
    myInput['gamma']=myInput['totalEnergy_eV']/myInput['particleMass_eV']
    myInput['beta']=np.sqrt(1-1/myInput['gamma']**2)

    image=image*myInput['eperimage']/myInput['dtbin']/myInput['dEbin']

    halfProfileLength=myInput['profilelength']/2.

    Toffset= (myInput['xat0']-halfProfileLength)*myInput['dtbin']*1e9
    Eoffset= (myInput['yat0']-halfProfileLength)*myInput['dEbin']/1e6

    t=np.arange(-halfProfileLength,halfProfileLength)*myInput['dtbin']*1e9-Toffset
    E=np.arange(-halfProfileLength,halfProfileLength)*myInput['dEbin']/1e6-Eoffset


    deltaP_P= 1/myInput['beta']**2*E*1e6/myInput['totalEnergy_eV']
    myProfile=np.sum(np.reshape(image, [myInput['profilelength'], myInput['profilelength']]),0)
    myProfile=myProfile/np.trapz(myProfile,deltaP_P)
    myInput['deltaP_P']=deltaP_P;
    myInput['myProfile']=myProfile;
    myInput['E_MeV']=E
    myInput['t_ns']=t
    myInput['phaseSpace_e_per_eVs']=np.reshape(image, [myInput['profilelength'], myInput['profilelength']]);
    myProfileNormalized=myProfile/np.trapz(myProfile,deltaP_P)
    myMean=np.trapz(deltaP_P*myProfileNormalized,deltaP_P)
    myRMS=np.sqrt(np.trapz((deltaP_P-myMean)**2*myProfileNormalized,deltaP_P))
    myInput['deltaP_P_RMS']=myRMS
    return myInput

# %%
# new tomogram analysis
files60 = sorted(glob.glob(folderPath+'/60kV_tomo/*.dat'))
# del(files60[10])
files70 = sorted(glob.glob(folderPath+'/70kV_tomo/*.dat'))
files80 = sorted(glob.glob(folderPath+'/80kV_tomo/*.dat'))
files0 = sorted(glob.glob(folderPath+'/zero_kick_tomo/*.dat'))
files0_2 = sorted(glob.glob(folderPath+'/zero_kick_after_tomo/*.dat'))
files_tomo = files0+files60+files70+files80+files0_2

tomo_data = pnd.DataFrame()

for f in range(len(files_tomo)):
    try:
        tomo_d = extractProfile(files_tomo[f])
        tomo_d['Filename'] = files_tomo[f]
        if tomo_d is np.nan:
            pass
        else:
            tomo_data=tomo_data.append(tomo_d,ignore_index=True)
    except IOError:
        print '\nIOError\n'

# %%
timeTolerance = 22

# ---------- Vars initialisation
myDataFrame['tomoTimestamp']=np.nan
myDataFrame['tomoDelta']=np.nan
myDataFrame['tomoFilename']=np.str
myDataFrame['deltaP_P_rms']=np.nan
myDataFrame['peakLineDensity']=np.nan
myDataFrame['beta']=np.nan
myDataFrame['gamma']=np.nan
myDataFrame['deltaP_P']=[np.empty(0,dtype=float)]*len(myDataFrame)
myDataFrame['momentumProfile']=[np.empty(0,dtype=float)]*len(myDataFrame)


succ_count = 0
last_match = 0
# loop over the tomo_timestamps
for k in range(len(tomo_data)):
    tomo_local_cs = tomo_data['cycleStamp'].values[k]
    t = myToolbox.unixtime2datetime(tomo_local_cs)
    tomo_fname = tomo_data['Filename'].iloc[k]
    tomo_dpprms = tomo_data['deltaP_P_RMS'].iloc[k]
#     tomo_pkldens = tomo_data['peakLineDensity'].iloc[k]
    betar = tomo_data['beta'].iloc[k]
    gammar = tomo_data['gamma'].iloc[k]
    dpp_profil = tomo_data['deltaP_P'].iloc[k]
    p_profil = tomo_data['myProfile'].iloc[k]    


    # loop over the matlab data
    for x in range(len(myDataFrame)):
        c = myToolbox.unixtime2utcdatetime(myDataFrame['cycleStamp'].values[x]*1e-9)
        d = t-c
        d = d.total_seconds()

        if np.abs(d) <= timeTolerance and x > last_match: #avoid match the same tomogram to more matlab acquisition unintentionally
            myDataFrame['tomoTimestamp'].iloc[x] = tomo_local_cs
            myDataFrame['tomoFilename'].iloc[x] = tomo_fname
            myDataFrame['tomoDelta'].iloc[x] = d
            myDataFrame['deltaP_P_rms'].iloc[x]= tomo_dpprms
#             myDataFrame['peakLineDensity'].iloc[x]= tomo_pkldens
            myDataFrame['beta'].iloc[x]= betar
            myDataFrame['gamma'].iloc[x]= gammar
            myDataFrame['deltaP_P'].iloc[x]= dpp_profil
            myDataFrame['momentumProfile'].iloc[x]= p_profil


            succ_count += 1 #dummy counter
            
print str(succ_count) +"/"+ str(len(tomo_data)) +" are within the timeTolerance"
print 'length of dataframe is: '+ str(len(myDataFrame))
# Out:
# 0/0 are within the timeTolerance
# length of dataframe is: 84

# %%
# discard the elements without tomogram
discFlag = np.isnan(myDataFrame['tomoDelta'].values)
myDataFrame = myDataFrame.drop(myDataFrame.loc[discFlag].index)

# %%
np.sqrt(1-((0.938/26)**2)) # beta
# Out:
# 0.99934901592051506

# %%
26/0.938 # gamma
# Out:
# 27.71855010660981

# %%
myDataFrame['beta'] = np.sqrt(1-((0.938/26)**2))
myDataFrame['gamma'] = 26/0.938
myDataFrame['deltaP_P_rms'] = 0.48e-3

# %% [markdown]
# # Save the imported data

# %%
myDataFrame.to_pickle('imported_data_2018.07.24.pkl')

# %%
# myDataFrame=pnd.read_pickle('imported_data_2018.07.24.pkl')

# %%
myDataFrame['PI2_KFA45.CCV.value']
# Out:
# 2018-07-24 13:34:42.700      0.0
# 2018-07-24 13:35:19.900      0.0
# 2018-07-24 13:36:34.300      0.0
# 2018-07-24 13:37:11.500      0.0
# 2018-07-24 13:37:48.700      0.0
# 2018-07-24 13:38:25.900      0.0
# 2018-07-24 13:39:03.100      0.0
# 2018-07-24 13:39:40.300      0.0
# 2018-07-24 13:40:17.500      0.0
# 2018-07-24 13:40:54.700      0.0
# 2018-07-24 13:41:31.900      0.0
# 2018-07-24 13:42:09.100     60.0
# 2018-07-24 13:42:46.300     60.0
# 2018-07-24 13:43:23.500     60.0
# 2018-07-24 13:44:00.700     60.0
# 2018-07-24 13:44:37.900     60.0
# 2018-07-24 13:45:15.100     60.0
# 2018-07-24 13:45:52.300     60.0
# 2018-07-24 13:46:29.500     60.0
# 2018-07-24 13:47:06.700     60.0
# 2018-07-24 13:47:43.900     80.0
# 2018-07-24 13:48:21.100     80.0
# 2018-07-24 13:48:58.300     80.0
# 2018-07-24 13:49:35.500     80.0
# 2018-07-24 13:50:12.700     80.0
# 2018-07-24 13:50:49.900     80.0
# 2018-07-24 13:51:27.100     80.0
# 2018-07-24 13:52:04.300     80.0
# 2018-07-24 13:52:41.500     80.0
# 2018-07-24 13:53:18.700     80.0
#                            ...
# 2018-07-24 14:08:48.700    140.0
# 2018-07-24 14:09:25.900    140.0
# 2018-07-24 14:10:03.100    140.0
# 2018-07-24 14:10:40.300    140.0
# 2018-07-24 14:11:17.500    140.0
# 2018-07-24 14:11:54.700    140.0
# 2018-07-24 14:12:31.900    160.0
# 2018-07-24 14:13:09.100    160.0
# 2018-07-24 14:13:46.300    160.0
# 2018-07-24 14:14:23.500    160.0
# 2018-07-24 14:15:00.700    160.0
# 2018-07-24 14:15:37.900    160.0
# 2018-07-24 14:16:15.100    160.0
# 2018-07-24 14:16:52.300    160.0
# 2018-07-24 14:17:29.500    160.0
# 2018-07-24 14:18:06.700    160.0
# 2018-07-24 14:18:43.900    180.0
# 2018-07-24 14:19:21.100    180.0
# 2018-07-24 14:19:58.300    180.0
# 2018-07-24 14:20:35.500    180.0
# 2018-07-24 14:21:12.700    180.0
# 2018-07-24 14:21:49.900    180.0
# 2018-07-24 14:22:27.100    180.0
# 2018-07-24 14:23:04.300    180.0
# 2018-07-24 14:23:41.500    180.0
# 2018-07-24 14:24:18.700    180.0
# 2018-07-24 14:24:55.900    180.0
# 2018-07-24 14:25:33.100    180.0
# 2018-07-24 14:26:10.300    180.0
# 2018-07-24 14:26:47.500    180.0
# Name: PI2_KFA45.CCV.value, Length: 84, dtype: float64

# %% [markdown]
# # Intensity

# %%
myDataFrame['Intensity'] = myDataFrame['PR_BCT_ST.Samples.value.samples']
myDataFrame['Losses'] = myDataFrame['Intensity'].apply(lambda x: 1-x[:][1400]/x[1350] )

# %%
plt.plot(myDataFrame['Intensity'].apply(lambda x: np.max(x)),'*')
plt.xlabel('Kicker strength K')
plt.ylabel('Peak intensity (10^10 ppb)')
# Out:
# Text(0,0.5,u'Peak intensity (10^10 ppb)')

# %%
plt.plot(np.linspace(0,len(myDataFrame)-1,len(myDataFrame)),myDataFrame['Losses'],'*')
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,0,0.05))
plt.xlabel('Time ')
plt.ylabel('Losses')
# Out:
# Text(0,0.5,u'Losses')

# %%
for ll in range(10):
    plt.plot(myDataFrame['Intensity'].values[ll])
    
plt.axvline(x=1350, ymin=0, ymax = 8, linewidth=2, color='k')
plt.axvline(x=1400, ymin=0, ymax = 8, linewidth=2, color='k')
plt.xlabel('Cycle time (ms)')
plt.ylabel('BCT Intensity (*1e10 ppb)')
plt.title('10 shots intensity')
# Out:
# Text(0.5,1,u'10 shots intensity')

# %% [markdown]
# # Calculate wire scanner emittance
# ## X plane
# ### Traditional method

# %%
# Wirescanner sigma
#position data cleanup (sort, get unique values and the idxes) and conversion to mm
myDataFrame['BWS65_position'] = myDataFrame['PR_BWS_65_H_ROT.Acquisition.value.projPositionSet1'].apply(lambda x: np.unique(x, return_index=True)[0]*1e-3)
myDataFrame['BWS65_position_idx'] = myDataFrame['PR_BWS_65_H_ROT.Acquisition.value.projPositionSet1'].apply(lambda x: np.unique(x, return_index=True)[1])

#instantiate an array object for the result in the frame
myDataFrame['BWS65_data'] = myDataFrame['BWS65_position_idx'].apply(lambda x: np.empty(len(x)))
pos = np.arange(-50, 50, 0.05)

row, col = myDataFrame.shape

for r in xrange(row):
    myDataFrame['BWS65_data'].iloc[r] = np.interp(pos, myDataFrame['BWS65_position'].iloc[r], myDataFrame['PR_BWS_65_H_ROT.Acquisition.value.projDataSet1'].iloc[r][myDataFrame['BWS65_position_idx'].iloc[r]])  
    
#do the fit and get the sigma in mm
myDataFrame['WS_fit_results_x'] = myDataFrame['BWS65_data'].apply(lambda x: myToolbox.makeGaussianFit_5_parameters(pos,x))
myDataFrame['WS_sigma_x'] = myDataFrame['WS_fit_results_x'].apply(lambda x: x[0][-1])

# %%
# Emittance calculation
myDataFrame['WS_emittance_x'] = np.nan
myDataFrame['WS_geom_emittance_x'] = np.nan

for n in range(len(myDataFrame)):
    myDataFrame['WS_emittance_x'].iloc[n] = normalised_emittance('65H',myDataFrame['WS_sigma_x'].values[n],dp=myDataFrame['deltaP_P_rms'].values[n])
    myDataFrame['WS_geom_emittance_x'].iloc[n] = myDataFrame['WS_emittance_x'].iloc[n]/(myDataFrame['beta'].iloc[n]*myDataFrame['gamma'].iloc[n])

# %% [markdown]
# ### Dispersive profile deconvolution

# %% [raw]
# # BWS65
# betax = 21.77988929
# Dx = 3.24577470
#
# betax = 20.11
# Dx = 3.2
#
# def deconv_caller(row):
#     return myToolbox.computeTransverseEmittance(row['PR_BWS_65_H_ROT.Acquisition.value.projPositionSet1'],
#                               row['PR_BWS_65_H_ROT.Acquisition.value.projDataSet1'],
#                               row['momentumProfile'],
#                               row['deltaP_P'],
#                               row['beta']*row['gamma'],
#                               betaOptical_m=betax,Dispersion_m=Dx)
#
# myDataFrame['Deconvolution_result'] = myDataFrame.apply(deconv_caller,axis=1)
#
#
#
# for k in myDataFrame.index:
#     myDataFrame.loc[k,'Emittance_x_deconv'] = myDataFrame.loc[k,('Deconvolution_result')]['emittance_um']

# %% [markdown]
# ## Y plane

# %%
# Wirescanner sigma
#position data cleanup (sort, get unique values and the idxes) and conversion to mm
myDataFrame['BWS85_position'] = myDataFrame['PR_BWS_85_V_ROT.Acquisition.value.projPositionSet1'].apply(lambda x: np.unique(x, return_index=True)[0]*1e-3)
myDataFrame['BWS85_position_idx'] = myDataFrame['PR_BWS_85_V_ROT.Acquisition.value.projPositionSet1'].apply(lambda x: np.unique(x, return_index=True)[1])

#instantiate an array object for the result in the frame
myDataFrame['BWS85_data'] = myDataFrame['BWS85_position_idx'].apply(lambda x: np.empty(len(x)))
pos = np.arange(-50, 50, 0.05)

row, col = myDataFrame.shape

for r in xrange(row):
    myDataFrame['BWS85_data'].iloc[r] = np.interp(pos, myDataFrame['BWS85_position'].iloc[r], myDataFrame['PR_BWS_85_V_ROT.Acquisition.value.projDataSet1'].iloc[r][myDataFrame['BWS85_position_idx'].iloc[r]])  

#do the fit and get the sigma in mm
myDataFrame['WS_fit_results_y'] = myDataFrame['BWS85_data'].apply(lambda x: myToolbox.makeGaussianFit_5_parameters(pos,x))
myDataFrame['WS_sigma_y'] = myDataFrame['WS_fit_results_y'].apply(lambda x: x[0][-1])

# %%
# Emittance calculation
myDataFrame['WS_emittance_y'] = myDataFrame['WS_sigma_y'].apply(lambda x: normalised_emittance('85V',x))

myDataFrame['WS_geom_emittance_y'] = np.nan
for n in range(len(myDataFrame)):
    myDataFrame['WS_geom_emittance_y'].iloc[n] = myDataFrame['WS_emittance_y'].iloc[n]/(myDataFrame['beta'].iloc[n]*myDataFrame['gamma'].iloc[n])

# %% [markdown]
# ## Calculate average emittance per measurement point

# %%
# find indexes of the shots at the same kick
ks = []
ks_idx = []
for k in range(len(myDataFrame)):
    if k == 0 :
        prevk = myDataFrame['PI2_KFA45.CCV.value'].iloc[k]
        ks.append(prevk)
        ks_idx.append(k)
        continue
#     print(k)
    
    thisk = myDataFrame['PI2_KFA45.CCV.value'].iloc[k]
    if (prevk-thisk) != 0:
#         print(thisk)
        ks.append(thisk)
        ks_idx.append(k)
    prevk = thisk

# %% [raw]
# # for checking ...
# for k in range(len(ks_idx)):
#     if k==len(ks_idx)-1:
#         print(myDataFrame['PI2_KFA45.CCV.value'].iloc[ks_idx[k]:])
#     else:
#         print(myDataFrame['PI2_KFA45.CCV.value'].iloc[ks_idx[k]:ks_idx[k+1]])

# %%
k_values = np.array((myDataFrame['PI2_KFA45.CCV.value'].iloc[ks_idx]))

emix_mean = np.empty(len(ks_idx),dtype=float)
emiy_mean = np.empty(len(ks_idx),dtype=float)
emix_std = np.empty(len(ks_idx),dtype=float)
emiy_std = np.empty(len(ks_idx),dtype=float)


for k in range(len(ks_idx)):
    if k==len(ks_idx)-1:
        emix_mean[k] = np.mean(myDataFrame['WS_geom_emittance_x'].iloc[ks_idx[k]:]) # the last tranche to close the array
        emiy_mean[k] = np.mean(myDataFrame['WS_geom_emittance_y'].iloc[ks_idx[k]:]) # the last tranche to close the array
        emix_std[k] = np.std(myDataFrame['WS_geom_emittance_x'].iloc[ks_idx[k]:]) # the last tranche to close the array
        emiy_std[k] = np.std(myDataFrame['WS_geom_emittance_y'].iloc[ks_idx[k]:]) # the last tranche to close the array
    else:
        emix_mean[k] = np.mean(myDataFrame['WS_geom_emittance_x'].iloc[ks_idx[k]:ks_idx[k+1]]) 
        emiy_mean[k] = np.mean(myDataFrame['WS_geom_emittance_y'].iloc[ks_idx[k]:ks_idx[k+1]]) 
        emix_std[k] = np.std(myDataFrame['WS_geom_emittance_x'].iloc[ks_idx[k]:ks_idx[k+1]]) 
        emiy_std[k] = np.std(myDataFrame['WS_geom_emittance_y'].iloc[ks_idx[k]:ks_idx[k+1]])

# %% [markdown]
# ## Emittance plot

# %%
fig, ax = plt.subplots(1)

ax.errorbar(k_values, emix_mean, yerr=emix_std, fmt='o',label='emi_x')
ax.errorbar(k_values, emiy_mean, yerr=emiy_std, fmt='o',label='emi_y')

plt.xlabel('Kicker voltage (kV)')
plt.ylabel('Geom. emittance (mm.mrad)')
# set axis to get rid of some bad shots
x1,x2,y1,y2 = plt.axis()
# plt.axis((x1,x2,4,6.2))



plt.legend(frameon=True)

fig.savefig('BCMS_under_coupling_emi_xy.eps', format='eps')

# %% [markdown]
# ## Get the voltage to kick calibration

# %%
fig, ax = plt.subplots(1)

kicks = KFA45_volt_to_kick(k_values, 26)

ax.errorbar(1e3*kicks, emix_mean, yerr=emix_std, fmt='o',label='emi_x')
ax.errorbar(1e3*kicks, emiy_mean, yerr=emiy_std, fmt='o',label='emi_y')

plt.xlabel('Kick (mrad)')
plt.ylabel('Geom. emittance (mm.mrad)')
# set axis to get rid of some bad shots
x1,x2,y1,y2 = plt.axis()
# plt.axis((x1,x2,4,6.2))


### ANALYTICAL EXPECTATION
def emi_th(kick, epsg_0):
    beta = 22.24
    return epsg_0 + 0.5*beta*(kick**2)

kick_plt = np.linspace(-0.01, 0.22)
plt.plot(1e3*kicks, 1e6*emi_th(kicks, 1e-6*emix_mean[0]), 'ro', label='Expectation')
plt.plot(kick_plt, 1e6*emi_th(1e-3*kick_plt, 1e-6*emix_mean[0]), 'r-')

plt.legend(frameon=True)

fig.savefig('emi_xy.eps', format='eps')

# %% [markdown]
# # BPMs

# %%
myDataFrame['']
# Out:
# array([-0.0484231 ,  0.22565179,  0.27133093,  0.31701008, -0.0484231 ])

# %%
# BPMs
# BPMs
myDataFrame['BPMx'] = myDataFrame['PR_BPM.AcquisitionTrajectoryBBB.value.position'].apply(lambda x: 0.1*x[0:43,:])
myDataFrame['BPMy'] = myDataFrame['PR_BPM.AcquisitionTrajectoryBBB.value.position'].apply(lambda x: 0.1*x[-43:,:])

#legacy from now on
#add field for the first two turns and splitting x and y pickups
myDataFrame['BPMx_turn1'] = myDataFrame['PR_BPM.AcquisitionTrajectoryBBB.value.position'].apply(lambda x: x[0:43,0])
myDataFrame['BPMy_turn1'] = myDataFrame['PR_BPM.AcquisitionTrajectoryBBB.value.position'].apply(lambda x: x[-43:,0])
myDataFrame['BPMx_turn2'] = myDataFrame['PR_BPM.AcquisitionTrajectoryBBB.value.position'].apply(lambda x: x[0:43,1])
myDataFrame['BPMy_turn2'] = myDataFrame['PR_BPM.AcquisitionTrajectoryBBB.value.position'].apply(lambda x: x[-43:,1])
# #turn to millimiters and cast in float
myDataFrame['BPMx_turn1'] = myDataFrame['BPMx_turn1'].apply(lambda x: x/10.)
myDataFrame['BPMy_turn1'] = myDataFrame['BPMy_turn1'].apply(lambda x: x/10.)
myDataFrame['BPMx_turn2'] = myDataFrame['BPMx_turn2'].apply(lambda x: x/10.)
myDataFrame['BPMy_turn2'] = myDataFrame['BPMy_turn2'].apply(lambda x: x/10.)
# #add orbit
myDataFrame['Orbit_x'] = myDataFrame['PR_BPM.AcquisitionOrbit.value.position'].apply(lambda x: x[0:43,1])
myDataFrame['Orbit_y'] = myDataFrame['PR_BPM.AcquisitionOrbit.value.position'].apply(lambda x: x[-43:,1])
myDataFrame['Orbit_x'] = myDataFrame['Orbit_x'].apply(lambda x: x/10.)
myDataFrame['Orbit_y'] = myDataFrame['Orbit_y'].apply(lambda x: x/10.)

# %%
# get the twiss at the BPMs position
optics_names = optics.NAME
BPM_name = []
BPM_idx = []
BPM_betax = []
BPM_alphax = []
BPM_betay = []
BPM_alphay = []

for k in range(len(optics_names)):
    if optics_names[k].find('PR.BPM') != -1:
#        print optics_names[k]
        BPM_name.append(optics_names[k])
        BPM_idx.append(k)
        BPM_betax.append(optics.BETA11[k])   
        BPM_alphax.append(optics.ALFA11[k])
        BPM_betay.append(optics.BETA22[k])   
        BPM_alphay.append(optics.ALFA22[k])

# for some reason the last bpm is the 00, place it back at the beginning
BPM_name = [BPM_name[-1]] + BPM_name[:-1]
BPM_idx = [BPM_idx[-1]] + BPM_idx[:-1]
BPM_betax = [BPM_betax[-1]] + BPM_betax[:-1]
BPM_alphax = [BPM_alphax[-1]] + BPM_alphax[:-1]
BPM_betay = [BPM_betay[-1]] + BPM_betay[:-1]
BPM_alphay = [BPM_alphay[-1]] + BPM_alphay[:-1]

# casting stuff
BPM_betax = np.array(BPM_betax)
BPM_alphax = np.array(BPM_alphax)
BPM_betay = np.array(BPM_betay)
BPM_alphay = np.array(BPM_alphay)

# %% [markdown]
# ## Get the transfer matrix between the BPMs
#
# So for example for BPM00 and BPM03
#
# $$
# \begin{pmatrix}
#   x  \\
#   x^\prime
#  \end{pmatrix}_\text{BPM00}
# =
# \begin{pmatrix}
#   a & b \\
#   c & d
#  \end{pmatrix}
# \begin{pmatrix}
#   x  \\
#   x^\prime
#  \end{pmatrix}_\text{BPM03}
# $$
#
# so the angle at the first BPM can be obtained just from the position at the two, if the optics model is known
# $$
# x^\prime_\text{BPM00} = c x_\text{BPM00} + \frac{d}{b} (x_\text{BPM03} - a x_\text{BPM00})
# $$

# %%
# load transfer matrixes
X_TM = [] # --> X_TM[0] is the matrix between BPM03 and BPM00
Y_TM = []

for k in range(43):
    fname = 'sector'+str(k)+'.sec'
    imported_twiss = metaclass.twiss('/eos/user/e/esenes/PS-injection-steering/MADx/transfer_matrix_BPMs/6.21-6.185/'+fname)

    x_transfer_matrix = np.matrix([[imported_twiss.R11[-1], imported_twiss.R12[-1]],[imported_twiss.R21[-1], imported_twiss.R22[-1]]],dtype=float)
    y_transfer_matrix = np.matrix([[imported_twiss.R33[-1],imported_twiss.R34[-1]],[imported_twiss.R43[-1],imported_twiss.R44[-1]]],dtype=float)

    X_TM.append(x_transfer_matrix)
    Y_TM.append(y_transfer_matrix)

print('Done.')
# Out:
# Done.

# %%
def getAngle(transfer_matrix, thisBPM, nextBPM):
    a = transfer_matrix[0,0]
    b = transfer_matrix[0,1]
    c = transfer_matrix[1,0]
    d = transfer_matrix[1,1]
    return (c*thisBPM) + ((d/b)*(nextBPM - (a*thisBPM)))

# %% [markdown]
# ## Get the angles

# %%
turnNumber = 5000
BPM_n = 43

nanMatrix = np.empty((int(BPM_n),int(turnNumber)),dtype=float); nanMatrix[:]=np.nan
myDataFrame['BPMx_angle'] = [nanMatrix]*len(myDataFrame)
myDataFrame['BPMy_angle'] = [nanMatrix]*len(myDataFrame)

for name in myDataFrame.index:
    # init
    nanMatrixX = np.empty((int(BPM_n),int(turnNumber)),dtype=float); nanMatrixX[:]=np.nan
    nanMatrixY = np.empty((int(BPM_n),int(turnNumber)),dtype=float); nanMatrixY[:]=np.nan

    for k in range(BPM_n-1):
        # X BPMs
        thisBPM = myDataFrame['BPMx'].loc[name][k,:]
        nextBPM = myDataFrame['BPMx'].loc[name][k+1,:]

        nanMatrixX[k, :] = getAngle(X_TM[k], thisBPM, nextBPM) 

        # Y BPMs
        thisBPM = myDataFrame['BPMy'].loc[name][k,:]
        nextBPM = myDataFrame['BPMy'].loc[name][k+1,:]

        nanMatrixY[k, :] = getAngle(Y_TM[k], thisBPM, nextBPM) 
    #last BPM
    k = BPM_n-1

    thisBPM = myDataFrame['BPMx'].loc[name][k,:]
    nextBPM = myDataFrame['BPMx'].loc[name][0,:]
    nanMatrixX[k, :] = getAngle(X_TM[k], thisBPM, nextBPM) 

    thisBPM = myDataFrame['BPMy'].loc[name][k,:]
    nextBPM = myDataFrame['BPMy'].loc[name][0,:]
    nanMatrixY[k, :] = getAngle(Y_TM[k], thisBPM, nextBPM) 

    #store data
    myDataFrame['BPMx_angle'].loc[name] = nanMatrixX
    myDataFrame['BPMy_angle'].loc[name] = nanMatrixY

# %%
k=1
off = 0
m = 0
ydata1 = myDataFrame['PR_BPM.AcquisitionTrajectoryBBB.value.position'].apply(lambda x: 0.1*x[off+m,:50]).values[k] #thisBPM
ydata2 = myDataFrame['PR_BPM.AcquisitionTrajectoryBBB.value.position'].apply(lambda x: 0.1*x[off+m+1,:50]).values[k] #nextBPM

fig, ax = plt.subplots(1,2,figsize=(10,5))

ax[0].plot(ydata1,'o-',label='x at BPM00')

angles = getAngle(Y_TM[m], ydata1, ydata2)

ax[0].plot(angles,'o-',label='x\' at BPM00')
ax[0].legend(frameon=True, loc=1)

ax[1].plot(ydata1, angles,'.')
ax[1].set_xlabel('x (mm)')
ax[1].set_ylabel('x\' (mrad)')

fig.tight_layout()

# %% [markdown]
# # Calculate injection oscillation from the BPM

# %% [markdown]
# ## 1. Look at one BPM and calculate the oscillation over the first 50 turns

# %%
# get the beta at the BPMs position
optics_names = optics.NAME
BPM_name = []
BPM_idx = []
BPM_betax = []
BPM_alphax = []

for k in range(len(optics_names)):
    if optics_names[k].find('PR.BPM') != -1:
#        print optics_names[k]
        BPM_name.append(optics_names[k])
        BPM_idx.append(k)
        BPM_betax.append(optics.BETA11[k])   
        BPM_alphax.append(optics.ALFA11[k])

# for some reason the last bpm is the 00, place it back at the beginning
BPM_name = [BPM_name[-1]] + BPM_name[:-1]
BPM_idx = [BPM_idx[-1]] + BPM_idx[:-1]
BPM_betax = [BPM_betax[-1]] + BPM_betax[:-1]
BPM_alphax = [BPM_alphax[-1]] + BPM_alphax[:-1]

# %%
# loop over all the BPM --> in vertical ! 
verticalMode = False

if verticalMode:
    off = 43
else:
    off = 0

chi2_thr = 1.   
    
# fit an harmonic function through the oscillations and extrapolate the amplitude. 
# possible tunes (non integer part) have been restricted to be between .20 and .25 --> 2pi/5 and pi/2

from scipy.optimize import curve_fit
def f_to_fit(x, a, b, c, d):
    return a*np.sin(b*x + c) + d

xdata = np.linspace(0,30,30)
osc_amplitude = np.empty([len(myDataFrame),len(BPM_name)],dtype=float); osc_amplitude[:]=np.nan

# statistical check
chi2 = np.empty([len(myDataFrame),len(BPM_name)],dtype=float)

for m in range(len(BPM_name)):

    for k in range(len(myDataFrame)):
        ydata = myDataFrame['PR_BPM.AcquisitionTrajectoryBBB.value.position'].apply(lambda x: 0.1*x[off+m,0:30]).values[k]
        # starting values
        phase = 0.41*pi
        p0 = ([1.5*np.std(ydata), phase, 0.1*pi, np.mean(ydata)])
        # fit boundaries 
        bounds=([0.5*np.std(ydata), .8*pi/5, -pi, -np.inf],[3*np.std(ydata),pi/2.,pi,np.inf])

        try:
            p, cov = curve_fit(f_to_fit,xdata,ydata,bounds=bounds,p0=p0)
            osc_amplitude[k,m] = np.abs(p[0])

            yfit = f_to_fit(xdata, *p)
            chi2[k,m] = np.sum((yfit - ydata)**2)/len(yfit)
            while chi2[k,m] > chi2_thr:
                print('chi2 = '+str(chi2[k,m])+' exceding the limit')

                phase += 0.03
                p0 = ([1.5*np.std(ydata), phase, -pi/2, np.mean(ydata)])
                p, cov = curve_fit(f_to_fit,xdata,ydata,bounds=bounds,p0=p0)
                osc_amplitude[k,m] = np.abs(p[0])

                yfit = f_to_fit(xdata, *p)
                chi2[k,m] = np.sum((yfit - ydata)**2)/len(yfit)
                print('Refitting, new chi2 = '+str(chi2[k,m]))
                
                if phase > 0.45*pi:
                    print('END phase reached')
                    raise RuntimeError


        except RuntimeError:
            print 'fit do not converge on shot '+str(k)
            osc_amplitude[k,m] = np.nan
            chi2[k,m] = np.nan
        
    print BPM_name[m] + ' processed with success '+ str(np.count_nonzero(~np.isnan(osc_amplitude[:,m]))) +'/'+str(len(myDataFrame))+' shots'
            
print 'Done.'
# Out:
# chi2 = 1.08250048835 exceding the limit
# Refitting, new chi2 = 0.315639559958
# chi2 = 1.72858790813 exceding the limit
# Refitting, new chi2 = 0.447915798441
# chi2 = 1.49729464583 exceding the limit
# Refitting, new chi2 = 0.589103142032
# chi2 = 1.49861896949 exceding the limit
# Refitting, new chi2 = 0.2963328793
# chi2 = 1.99780632831 exceding the limit
# Refitting, new chi2 = 0.615138099785
# chi2 = 2.5024640374 exceding the limit
# Refitting, new chi2 = 0.443042094832
# chi2 = 2.84594366867 exceding the limit
# Refitting, new chi2 = 0.454934950969
# chi2 = 2.3279684597 exceding the limit
# Refitting, new chi2 = 0.506222611753
# chi2 = 2.66102130448 exceding the limit
# Refitting, new chi2 = 0.659833134167
# chi2 = 2.24814943607 exceding the limit
# Refitting, new chi2 = 0.381343129002
# chi2 = 2.09344740696 exceding the limit
# Refitting, new chi2 = 0.655288973849
# chi2 = 4.35591009221 exceding the limit
# Refitting, new chi2 = 0.577634986264
# chi2 = 3.31483690813 exceding the limit
# Refitting, new chi2 = 0.567844384499
# chi2 = 3.85395636321 exceding the limit
# Refitting, new chi2 = 0.960382687489
# chi2 = 4.60489900958 exceding the limit
# Refitting, new chi2 = 0.406256576888
# chi2 = 5.7116450444 exceding the limit
# Refitting, new chi2 = 0.941067064206
# chi2 = 2.45270281266 exceding the limit
# Refitting, new chi2 = 0.412268311782
# chi2 = 3.78570797455 exceding the limit
# Refitting, new chi2 = 0.919098566441
# chi2 = 3.87218765024 exceding the limit
# Refitting, new chi2 = 0.578530612189
# chi2 = 4.4125467531 exceding the limit
# Refitting, new chi2 = 0.94194098726
# chi2 = 4.35807005233 exceding the limit
# Refitting, new chi2 = 0.517671067856
# chi2 = 3.9001882134 exceding the limit
# Refitting, new chi2 = 0.617395513711
# chi2 = 3.29978684158 exceding the limit
# Refitting, new chi2 = 0.443043431676
# chi2 = 4.89407559563 exceding the limit
# Refitting, new chi2 = 0.682210378784
# chi2 = 5.50761723158 exceding the limit
# Refitting, new chi2 = 0.839202496457
# chi2 = 4.77939156274 exceding the limit
# Refitting, new chi2 = 0.713097888844
# chi2 = 6.41066784514 exceding the limit
# Refitting, new chi2 = 0.852776264832
# chi2 = 5.40955786883 exceding the limit
# Refitting, new chi2 = 0.818087590334
# chi2 = 6.58638630048 exceding the limit
# Refitting, new chi2 = 0.902679698697
# chi2 = 4.91869004959 exceding the limit
# Refitting, new chi2 = 0.841684141389
# chi2 = 5.38708572942 exceding the limit
# Refitting, new chi2 = 0.583186176105
# chi2 = 7.15622064032 exceding the limit
# Refitting, new chi2 = 0.756374835896
# PR.BPM00 processed with success 129/129 shots
# chi2 = 1.15995829342 exceding the limit
# Refitting, new chi2 = 0.395897869983
# PR.BPM03 processed with success 129/129 shots
# chi2 = 1.41962302712 exceding the limit
# Refitting, new chi2 = 0.451671151629
# PR.BPM05 processed with success 129/129 shots
# chi2 = 1.04711030629 exceding the limit
# Refitting, new chi2 = 2.23429344791
# chi2 = 2.23429344791 exceding the limit
# Refitting, new chi2 = 2.23429344791
# chi2 = 2.23429344791 exceding the limit
# Refitting, new chi2 = 12.6748425218
# chi2 = 12.6748425218 exceding the limit
# Refitting, new chi2 = 1.0471103063
# chi2 = 1.0471103063 exceding the limit
# Refitting, new chi2 = 1.04711030632
# END phase reached
# fit do not converge on shot 2
# chi2 = 1.02935498532 exceding the limit
# Refitting, new chi2 = 1.20840242302
# chi2 = 1.20840242302 exceding the limit
# Refitting, new chi2 = 1.20840242302
# chi2 = 1.20840242302 exceding the limit
# Refitting, new chi2 = 4.40781723548
# chi2 = 4.40781723548 exceding the limit
# Refitting, new chi2 = 4.40781723543
# chi2 = 4.40781723543 exceding the limit
# Refitting, new chi2 = 4.40781723542
# END phase reached
# fit do not converge on shot 31
# chi2 = 2.07466821422 exceding the limit
# Refitting, new chi2 = 0.469457204574
# chi2 = 1.43278706653 exceding the limit
# Refitting, new chi2 = 1.43278706653
# chi2 = 1.43278706653 exceding the limit
# Refitting, new chi2 = 1.43278706653
# chi2 = 1.43278706653 exceding the limit
# Refitting, new chi2 = 1.43278706653
# chi2 = 1.43278706653 exceding the limit
# Refitting, new chi2 = 4.25676261
# chi2 = 4.25676261 exceding the limit
# Refitting, new chi2 = 4.25676260918
# END phase reached
# fit do not converge on shot 41
# chi2 = 2.85437243961 exceding the limit
# Refitting, new chi2 = 0.95878209946
# chi2 = 3.65173441172 exceding the limit
# Refitting, new chi2 = 0.786296027323
# chi2 = 2.44137309021 exceding the limit
# Refitting, new chi2 = 0.643635970847
# chi2 = 1.14675036469 exceding the limit
# Refitting, new chi2 = 1.14675036469
# chi2 = 1.14675036469 exceding the limit
# Refitting, new chi2 = 1.1467503647
# chi2 = 1.1467503647 exceding the limit
# Refitting, new chi2 = 1.14675036469
# chi2 = 1.14675036469 exceding the limit
# Refitting, new chi2 = 1.14675036469
# chi2 = 1.14675036469 exceding the limit
# Refitting, new chi2 = 1.14675036469
# END phase reached
# fit do not converge on shot 72
# chi2 = 1.0319066192 exceding the limit
# Refitting, new chi2 = 1.03190661866
# chi2 = 1.03190661866 exceding the limit
# Refitting, new chi2 = 1.03190661865
# chi2 = 1.03190661865 exceding the limit
# Refitting, new chi2 = 1.03190661865
# chi2 = 1.03190661865 exceding the limit
# Refitting, new chi2 = 1.0319066187
# chi2 = 1.0319066187 exceding the limit
# Refitting, new chi2 = 1.03190661905
# END phase reached
# fit do not converge on shot 93
# chi2 = 1.00915667475 exceding the limit
# Refitting, new chi2 = 1.00915667474
# chi2 = 1.00915667474 exceding the limit
# Refitting, new chi2 = 1.00915667477
# chi2 = 1.00915667477 exceding the limit
# Refitting, new chi2 = 1.00915667486
# chi2 = 1.00915667486 exceding the limit
# Refitting, new chi2 = 1.00915667478
# chi2 = 1.00915667478 exceding the limit
# Refitting, new chi2 = 1.0091566748
# END phase reached
# fit do not converge on shot 104
# chi2 = 1.12682076849 exceding the limit
# Refitting, new chi2 = 1.1268207685
# chi2 = 1.1268207685 exceding the limit
# Refitting, new chi2 = 1.12682076855
# chi2 = 1.12682076855 exceding the limit
# Refitting, new chi2 = 1.12682076856
# chi2 = 1.12682076856 exceding the limit
# Refitting, new chi2 = 1.12682076849
# chi2 = 1.12682076849 exceding the limit
# Refitting, new chi2 = 1.1268207685
# END phase reached
# fit do not converge on shot 108
# chi2 = 1.03289420414 exceding the limit
# Refitting, new chi2 = 1.03289420406
# chi2 = 1.03289420406 exceding the limit
# Refitting, new chi2 = 1.03289420407
# chi2 = 1.03289420407 exceding the limit
# Refitting, new chi2 = 1.03289420411
# chi2 = 1.03289420411 exceding the limit
# Refitting, new chi2 = 1.03289420407
# chi2 = 1.03289420407 exceding the limit
# Refitting, new chi2 = 1.03289420407
# END phase reached
# fit do not converge on shot 110
# chi2 = 1.19364558582 exceding the limit
# Refitting, new chi2 = 1.19364558582
# chi2 = 1.19364558582 exceding the limit
# Refitting, new chi2 = 1.19364558582
# chi2 = 1.19364558582 exceding the limit
# Refitting, new chi2 = 1.19364558582
# chi2 = 1.19364558582 exceding the limit
# Refitting, new chi2 = 1.19364558582
# chi2 = 1.19364558582 exceding the limit
# Refitting, new chi2 = 1.19364558582
# END phase reached
# fit do not converge on shot 121
# chi2 = 1.21351035537 exceding the limit
# Refitting, new chi2 = 1.21351035537
# chi2 = 1.21351035537 exceding the limit
# Refitting, new chi2 = 1.21351035537
# chi2 = 1.21351035537 exceding the limit
# Refitting, new chi2 = 1.21351035537
# chi2 = 1.21351035537 exceding the limit
# Refitting, new chi2 = 1.21351035538
# chi2 = 1.21351035538 exceding the limit
# Refitting, new chi2 = 1.2135103554
# END phase reached
# fit do not converge on shot 124
# PR.BPM07 processed with success 119/129 shots
# PR.BPM10 processed with success 129/129 shots
# chi2 = 1.12380144984 exceding the limit
# Refitting, new chi2 = 1.12380144985
# chi2 = 1.12380144985 exceding the limit
# Refitting, new chi2 = 1.12380144984
# chi2 = 1.12380144984 exceding the limit
# Refitting, new chi2 = 1.12380144988
# chi2 = 1.12380144988 exceding the limit
# Refitting, new chi2 = 1.12380144984
# chi2 = 1.12380144984 exceding the limit
# Refitting, new chi2 = 1.12380144985
# END phase reached
# fit do not converge on shot 19
# chi2 = 1.04063688282 exceding the limit
# Refitting, new chi2 = 6.79773482123
# chi2 = 6.79773482123 exceding the limit
# Refitting, new chi2 = 1.04063688282
# chi2 = 1.04063688282 exceding the limit
# Refitting, new chi2 = 1.0406368827
# chi2 = 1.0406368827 exceding the limit
# Refitting, new chi2 = 1.04063688265
# chi2 = 1.04063688265 exceding the limit
# Refitting, new chi2 = 1.04063688268
# END phase reached
# fit do not converge on shot 127
# PR.BPM13 processed with success 127/129 shots
# chi2 = 1.04564408487 exceding the limit
# Refitting, new chi2 = 1.04564408478
# chi2 = 1.04564408478 exceding the limit
# Refitting, new chi2 = 1.04564408478
# chi2 = 1.04564408478 exceding the limit
# Refitting, new chi2 = 1.04564408481
# chi2 = 1.04564408481 exceding the limit
# Refitting, new chi2 = 1.04564408488
# chi2 = 1.04564408488 exceding the limit
# Refitting, new chi2 = 1.04564408478
# END phase reached
# fit do not converge on shot 20
# chi2 = 1.02644093634 exceding the limit
# Refitting, new chi2 = 1.02644093634
# chi2 = 1.02644093634 exceding the limit
# Refitting, new chi2 = 1.02644093634
# chi2 = 1.02644093634 exceding the limit
# Refitting, new chi2 = 1.02644093634
# chi2 = 1.02644093634 exceding the limit
# Refitting, new chi2 = 1.02644093634
# chi2 = 1.02644093634 exceding the limit
# Refitting, new chi2 = 1.02644093634
# END phase reached
# fit do not converge on shot 33
# chi2 = 1.10735558939 exceding the limit
# Refitting, new chi2 = 1.10735558946
# chi2 = 1.10735558946 exceding the limit
# Refitting, new chi2 = 1.1073555894
# chi2 = 1.1073555894 exceding the limit
# Refitting, new chi2 = 1.1073555894
# chi2 = 1.1073555894 exceding the limit
# Refitting, new chi2 = 1.10735558939
# chi2 = 1.10735558939 exceding the limit
# Refitting, new chi2 = 1.10735558939
# END phase reached
# fit do not converge on shot 71
# chi2 = 1.58707411079 exceding the limit
# Refitting, new chi2 = 1.58707411055
# chi2 = 1.58707411055 exceding the limit
# Refitting, new chi2 = 1.58707411064
# chi2 = 1.58707411064 exceding the limit
# Refitting, new chi2 = 1.58707411058
# chi2 = 1.58707411058 exceding the limit
# Refitting, new chi2 = 1.58707411056
# chi2 = 1.58707411056 exceding the limit
# Refitting, new chi2 = 1.58707411087
# END phase reached
# fit do not converge on shot 77
# chi2 = 1.00234592025 exceding the limit
# Refitting, new chi2 = 1.64779219809
# chi2 = 1.64779219809 exceding the limit
# Refitting, new chi2 = 1.00234592015
# chi2 = 1.00234592015 exceding the limit
# Refitting, new chi2 = 1.00234592041
# chi2 = 1.00234592041 exceding the limit
# Refitting, new chi2 = 1.00234592013
# chi2 = 1.00234592013 exceding the limit
# Refitting, new chi2 = 1.0023459204
# END phase reached
# fit do not converge on shot 78
# chi2 = 1.14184722197 exceding the limit
# Refitting, new chi2 = 1.73613731109
# chi2 = 1.73613731109 exceding the limit
# Refitting, new chi2 = 1.73613731104
# chi2 = 1.73613731104 exceding the limit
# Refitting, new chi2 = 3.41998739377
# chi2 = 3.41998739377 exceding the limit
# Refitting, new chi2 = 3.41998740328
# chi2 = 3.41998740328 exceding the limit
# Refitting, new chi2 = 1.14184722184
# END phase reached
# fit do not converge on shot 84
# chi2 = 1.08902031318 exceding the limit
# Refitting, new chi2 = 1.19085546237
# chi2 = 1.19085546237 exceding the limit
# Refitting, new chi2 = 2.85482231574
# chi2 = 2.85482231574 exceding the limit
# Refitting, new chi2 = 2.85482231804
# chi2 = 2.85482231804 exceding the limit
# Refitting, new chi2 = 1.08902031323
# chi2 = 1.08902031323 exceding the limit
# Refitting, new chi2 = 1.08902031322
# END phase reached
# fit do not converge on shot 89
# chi2 = 1.09418274805 exceding the limit
# Refitting, new chi2 = 2.78367371275
# chi2 = 2.78367371275 exceding the limit
# Refitting, new chi2 = 1.09418274803
# chi2 = 1.09418274803 exceding the limit
# Refitting, new chi2 = 1.09418274787
# chi2 = 1.09418274787 exceding the limit
# Refitting, new chi2 = 1.09418274777
# chi2 = 1.09418274777 exceding the limit
# Refitting, new chi2 = 1.09418274811
# END phase reached
# fit do not converge on shot 91
# chi2 = 2.97594754059 exceding the limit
# Refitting, new chi2 = 0.995238480642
# chi2 = 1.06775052732 exceding the limit
# Refitting, new chi2 = 1.60157780169
# chi2 = 1.60157780169 exceding the limit
# Refitting, new chi2 = 1.60157780179
# chi2 = 1.60157780179 exceding the limit
# Refitting, new chi2 = 1.60157780166
# chi2 = 1.60157780166 exceding the limit
# Refitting, new chi2 = 5.05873608241
# chi2 = 5.05873608241 exceding the limit
# Refitting, new chi2 = 1.06775052736
# END phase reached
# fit do not converge on shot 98
# chi2 = 3.84380821038 exceding the limit
# Refitting, new chi2 = 1.02625880398
# chi2 = 1.02625880398 exceding the limit
# Refitting, new chi2 = 1.02625880398
# chi2 = 1.02625880398 exceding the limit
# Refitting, new chi2 = 1.02625880398
# chi2 = 1.02625880398 exceding the limit
# Refitting, new chi2 = 4.07817125183
# chi2 = 4.07817125183 exceding the limit
# Refitting, new chi2 = 0.646893479918
# END phase reached
# fit do not converge on shot 102
# chi2 = 4.92966065576 exceding the limit
# Refitting, new chi2 = 0.996084414732
# chi2 = 4.59969781414 exceding the limit
# Refitting, new chi2 = 2.05756905736
# chi2 = 2.05756905736 exceding the limit
# Refitting, new chi2 = 2.05756905738
# chi2 = 2.05756905738 exceding the limit
# Refitting, new chi2 = 5.34874497048
# chi2 = 5.34874497048 exceding the limit
# Refitting, new chi2 = 1.08657601396
# chi2 = 1.08657601396 exceding the limit
# Refitting, new chi2 = 1.08657601395
# END phase reached
# fit do not converge on shot 106
# chi2 = 6.39252749687 exceding the limit
# Refitting, new chi2 = 1.70375500294
# chi2 = 1.70375500294 exceding the limit
# Refitting, new chi2 = 1.70375500294
# chi2 = 1.70375500294 exceding the limit
# Refitting, new chi2 = 1.70375500294
# chi2 = 1.70375500294 exceding the limit
# Refitting, new chi2 = 7.09794867095
# chi2 = 7.09794867095 exceding the limit
# Refitting, new chi2 = 0.594009788988
# END phase reached
# fit do not converge on shot 107
# chi2 = 4.73191121983 exceding the limit
# Refitting, new chi2 = 1.09877455473
# chi2 = 1.09877455473 exceding the limit
# Refitting, new chi2 = 1.09877455473
# chi2 = 1.09877455473 exceding the limit
# Refitting, new chi2 = 5.24691485622
# chi2 = 5.24691485622 exceding the limit
# Refitting, new chi2 = 5.24691485916
# chi2 = 5.24691485916 exceding the limit
# Refitting, new chi2 = 0.540490898523
# END phase reached
# fit do not converge on shot 109
# chi2 = 1.19316468023 exceding the limit
# Refitting, new chi2 = 3.11827634561
# chi2 = 3.11827634561 exceding the limit
# Refitting, new chi2 = 3.11827634561
# chi2 = 3.11827634561 exceding the limit
# Refitting, new chi2 = 13.1738789151
# chi2 = 13.1738789151 exceding the limit
# Refitting, new chi2 = 1.19316468024
# chi2 = 1.19316468024 exceding the limit
# Refitting, new chi2 = 1.19316468023
# END phase reached
# fit do not converge on shot 128
# PR.BPM15 processed with success 115/129 shots
# chi2 = 1.04775955905 exceding the limit
# Refitting, new chi2 = 1.04775955912
# chi2 = 1.04775955912 exceding the limit
# Refitting, new chi2 = 1.04775955904
# chi2 = 1.04775955904 exceding the limit
# Refitting, new chi2 = 1.04775955904
# chi2 = 1.04775955904 exceding the limit
# Refitting, new chi2 = 1.04775955907
# chi2 = 1.04775955907 exceding the limit
# Refitting, new chi2 = 1.04775955905
# END phase reached
# fit do not converge on shot 13
# chi2 = 1.4193159974 exceding the limit
# Refitting, new chi2 = 1.41931599741
# chi2 = 1.41931599741 exceding the limit
# Refitting, new chi2 = 1.4193159974
# chi2 = 1.4193159974 exceding the limit
# Refitting, new chi2 = 1.41931599741
# chi2 = 1.41931599741 exceding the limit
# Refitting, new chi2 = 1.4193159974
# chi2 = 1.4193159974 exceding the limit
# Refitting, new chi2 = 1.4193159974
# END phase reached
# fit do not converge on shot 29
# chi2 = 1.03190048478 exceding the limit
# Refitting, new chi2 = 1.03190048478
# chi2 = 1.03190048478 exceding the limit
# Refitting, new chi2 = 1.03190048478
# chi2 = 1.03190048478 exceding the limit
# Refitting, new chi2 = 1.0319004848
# chi2 = 1.0319004848 exceding the limit
# Refitting, new chi2 = 1.03190048484
# chi2 = 1.03190048484 exceding the limit
# Refitting, new chi2 = 1.03190048482
# END phase reached
# fit do not converge on shot 46
# chi2 = 1.0164985233 exceding the limit
# Refitting, new chi2 = 1.01649852336
# chi2 = 1.01649852336 exceding the limit
# Refitting, new chi2 = 1.01649852329
# chi2 = 1.01649852329 exceding the limit
# Refitting, new chi2 = 1.01649852336
# chi2 = 1.01649852336 exceding the limit
# Refitting, new chi2 = 1.01649852338
# chi2 = 1.01649852338 exceding the limit
# Refitting, new chi2 = 1.01649852336
# END phase reached
# fit do not converge on shot 56
# chi2 = 1.09170022722 exceding the limit
# Refitting, new chi2 = 1.09170022722
# chi2 = 1.09170022722 exceding the limit
# Refitting, new chi2 = 1.09170022721
# chi2 = 1.09170022721 exceding the limit
# Refitting, new chi2 = 1.09170022721
# chi2 = 1.09170022721 exceding the limit
# Refitting, new chi2 = 1.09170022722
# chi2 = 1.09170022722 exceding the limit
# Refitting, new chi2 = 1.09170022722
# END phase reached
# fit do not converge on shot 58
# chi2 = 1.65519567559 exceding the limit
# Refitting, new chi2 = 1.07470947516
# chi2 = 1.07470947516 exceding the limit
# Refitting, new chi2 = 1.07470947516
# chi2 = 1.07470947516 exceding the limit
# Refitting, new chi2 = 1.07470947516
# chi2 = 1.07470947516 exceding the limit
# Refitting, new chi2 = 1.73774628725
# chi2 = 1.73774628725 exceding the limit
# Refitting, new chi2 = 1.73774628728
# END phase reached
# fit do not converge on shot 72
# chi2 = 1.31077345163 exceding the limit
# Refitting, new chi2 = 1.02603538851
# chi2 = 1.02603538851 exceding the limit
# Refitting, new chi2 = 1.02603538851
# chi2 = 1.02603538851 exceding the limit
# Refitting, new chi2 = 1.02603538851
# chi2 = 1.02603538851 exceding the limit
# Refitting, new chi2 = 1.53528769172
# chi2 = 1.53528769172 exceding the limit
# Refitting, new chi2 = 1.53528769157
# END phase reached
# fit do not converge on shot 79
# chi2 = 2.34525645902 exceding the limit
# Refitting, new chi2 = 0.65814144194
# chi2 = 2.82420638842 exceding the limit
# Refitting, new chi2 = 1.01244684242
# chi2 = 1.01244684242 exceding the limit
# Refitting, new chi2 = 1.01244684242
# chi2 = 1.01244684242 exceding the limit
# Refitting, new chi2 = 1.01244684242
# chi2 = 1.01244684242 exceding the limit
# Refitting, new chi2 = 3.39329793171
# chi2 = 3.39329793171 exceding the limit
# Refitting, new chi2 = 0.863784293359
# END phase reached
# fit do not converge on shot 84
# chi2 = 1.91231665076 exceding the limit
# Refitting, new chi2 = 0.559663244741
# chi2 = 2.35453629327 exceding the limit
# Refitting, new chi2 = 0.836918957402
# chi2 = 1.59686996005 exceding the limit
# Refitting, new chi2 = 0.756207338208
# chi2 = 2.62456169844 exceding the limit
# Refitting, new chi2 = 0.711994364933
# chi2 = 4.67385432246 exceding the limit
# Refitting, new chi2 = 0.83144439069
# chi2 = 2.29288710822 exceding the limit
# Refitting, new chi2 = 0.456923207966
# chi2 = 4.39006360945 exceding the limit
# Refitting, new chi2 = 0.514369219423
# chi2 = 1.25660682929 exceding the limit
# Refitting, new chi2 = 1.25660682926
# chi2 = 1.25660682926 exceding the limit
# Refitting, new chi2 = 1.25660682953
# chi2 = 1.25660682953 exceding the limit
# Refitting, new chi2 = 1.25660682933
# chi2 = 1.25660682933 exceding the limit
# Refitting, new chi2 = 1.25660682953
# chi2 = 1.25660682953 exceding the limit
# Refitting, new chi2 = 11.634951606
# END phase reached
# fit do not converge on shot 112
# chi2 = 1.50686703868 exceding the limit
# Refitting, new chi2 = 1.50686703853
# chi2 = 1.50686703853 exceding the limit
# Refitting, new chi2 = 1.50686703854
# chi2 = 1.50686703854 exceding the limit
# Refitting, new chi2 = 1.50686703861
# chi2 = 1.50686703861 exceding the limit
# Refitting, new chi2 = 1.50686703848
# chi2 = 1.50686703848 exceding the limit
# Refitting, new chi2 = 11.357108978
# END phase reached
# fit do not converge on shot 124
# PR.BPM17 processed with success 119/129 shots
# chi2 = 1.21702677423 exceding the limit
# Refitting, new chi2 = 1.2170267746
# chi2 = 1.2170267746 exceding the limit
# Refitting, new chi2 = 1.21702677437
# chi2 = 1.21702677437 exceding the limit
# Refitting, new chi2 = 1.21702677438
# chi2 = 1.21702677438 exceding the limit
# Refitting, new chi2 = 1.21702677439
# chi2 = 1.21702677439 exceding the limit
# Refitting, new chi2 = 1.2170267744
# END phase reached
# fit do not converge on shot 31
# chi2 = 1.14833694825 exceding the limit
# Refitting, new chi2 = 1.14833694824
# chi2 = 1.14833694824 exceding the limit
# Refitting, new chi2 = 1.1483369483
# chi2 = 1.1483369483 exceding the limit
# Refitting, new chi2 = 1.14833694858
# chi2 = 1.14833694858 exceding the limit
# Refitting, new chi2 = 1.14833694825
# chi2 = 1.14833694825 exceding the limit
# Refitting, new chi2 = 1.14833694831
# END phase reached
# fit do not converge on shot 33
# chi2 = 1.05692507891 exceding the limit
# Refitting, new chi2 = 1.05692507906
# chi2 = 1.05692507906 exceding the limit
# Refitting, new chi2 = 1.05692507894
# chi2 = 1.05692507894 exceding the limit
# Refitting, new chi2 = 1.05692507898
# chi2 = 1.05692507898 exceding the limit
# Refitting, new chi2 = 1.05692507898
# chi2 = 1.05692507898 exceding the limit
# Refitting, new chi2 = 1.05692507889
# END phase reached
# fit do not converge on shot 38
# chi2 = 1.0595500516 exceding the limit
# Refitting, new chi2 = 1.85724755465
# chi2 = 1.85724755465 exceding the limit
# Refitting, new chi2 = 1.05955005163
# chi2 = 1.05955005163 exceding the limit
# Refitting, new chi2 = 1.05955005163
# chi2 = 1.05955005163 exceding the limit
# Refitting, new chi2 = 1.05955005168
# chi2 = 1.05955005168 exceding the limit
# Refitting, new chi2 = 1.05955005191
# END phase reached
# fit do not converge on shot 41
# chi2 = 1.10994120307 exceding the limit
# Refitting, new chi2 = 1.10994120315
# chi2 = 1.10994120315 exceding the limit
# Refitting, new chi2 = 1.10994120338
# chi2 = 1.10994120338 exceding the limit
# Refitting, new chi2 = 1.10994120307
# chi2 = 1.10994120307 exceding the limit
# Refitting, new chi2 = 1.10994120309
# chi2 = 1.10994120309 exceding the limit
# Refitting, new chi2 = 1.10994120307
# END phase reached
# fit do not converge on shot 71
# chi2 = 1.01400115282 exceding the limit
# Refitting, new chi2 = 1.01400115463
# chi2 = 1.01400115463 exceding the limit
# Refitting, new chi2 = 1.01400115129
# chi2 = 1.01400115129 exceding the limit
# Refitting, new chi2 = 1.01400115148
# chi2 = 1.01400115148 exceding the limit
# Refitting, new chi2 = 1.01391648634
# chi2 = 1.01391648634 exceding the limit
# Refitting, new chi2 = 1.01391648637
# END phase reached
# fit do not converge on shot 77
# chi2 = 1.13368024423 exceding the limit
# Refitting, new chi2 = 1.13368024427
# chi2 = 1.13368024427 exceding the limit
# Refitting, new chi2 = 1.13368024423
# chi2 = 1.13368024423 exceding the limit
# Refitting, new chi2 = 1.13368024427
# chi2 = 1.13368024427 exceding the limit
# Refitting, new chi2 = 1.13368024423
# chi2 = 1.13368024423 exceding the limit
# Refitting, new chi2 = 1.13368024431
# END phase reached
# fit do not converge on shot 88
# chi2 = 1.10570953159 exceding the limit
# Refitting, new chi2 = 1.10570953137
# chi2 = 1.10570953137 exceding the limit
# Refitting, new chi2 = 1.10570953143
# chi2 = 1.10570953143 exceding the limit
# Refitting, new chi2 = 1.10570953161
# chi2 = 1.10570953161 exceding the limit
# Refitting, new chi2 = 1.10570953141
# chi2 = 1.10570953141 exceding the limit
# Refitting, new chi2 = 1.10570953138
# END phase reached
# fit do not converge on shot 91
# chi2 = 1.32225806702 exceding the limit
# Refitting, new chi2 = 1.32225806673
# chi2 = 1.32225806673 exceding the limit
# Refitting, new chi2 = 1.32225806662
# chi2 = 1.32225806662 exceding the limit
# Refitting, new chi2 = 1.32225806673
# chi2 = 1.32225806673 exceding the limit
# Refitting, new chi2 = 1.32225806685
# chi2 = 1.32225806685 exceding the limit
# Refitting, new chi2 = 1.32225806662
# END phase reached
# fit do not converge on shot 94
# chi2 = 1.24362379153 exceding the limit
# Refitting, new chi2 = 1.24362379153
# chi2 = 1.24362379153 exceding the limit
# Refitting, new chi2 = 1.24362379153
# chi2 = 1.24362379153 exceding the limit
# Refitting, new chi2 = 1.24362379153
# chi2 = 1.24362379153 exceding the limit
# Refitting, new chi2 = 1.24362379153
# chi2 = 1.24362379153 exceding the limit
# Refitting, new chi2 = 1.24362379153
# END phase reached
# fit do not converge on shot 121
# chi2 = 1.01701152983 exceding the limit
# Refitting, new chi2 = 1.0170115299
# chi2 = 1.0170115299 exceding the limit
# Refitting, new chi2 = 1.01701152983
# chi2 = 1.01701152983 exceding the limit
# Refitting, new chi2 = 1.01701152985
# chi2 = 1.01701152985 exceding the limit
# Refitting, new chi2 = 1.01701152983
# chi2 = 1.01701152983 exceding the limit
# Refitting, new chi2 = 1.01701152983
# END phase reached
# fit do not converge on shot 122
# chi2 = 1.10179879674 exceding the limit
# Refitting, new chi2 = 1.10179879668
# chi2 = 1.10179879668 exceding the limit
# Refitting, new chi2 = 1.10179879686
# chi2 = 1.10179879686 exceding the limit
# Refitting, new chi2 = 1.10179879669
# chi2 = 1.10179879669 exceding the limit
# Refitting, new chi2 = 1.10179879666
# chi2 = 1.10179879666 exceding the limit
# Refitting, new chi2 = 1.10179879676
# END phase reached
# fit do not converge on shot 123
# PR.BPM20 processed with success 117/129 shots
# chi2 = 1.03070686666 exceding the limit
# Refitting, new chi2 = 2.10549205578
# chi2 = 2.10549205578 exceding the limit
# Refitting, new chi2 = 2.10549205579
# chi2 = 2.10549205579 exceding the limit
# Refitting, new chi2 = 10.2404426234
# chi2 = 10.2404426234 exceding the limit
# Refitting, new chi2 = 1.03070686669
# chi2 = 1.03070686669 exceding the limit
# Refitting, new chi2 = 1.03070686669
# END phase reached
# fit do not converge on shot 13
# chi2 = 1.09123882398 exceding the limit
# Refitting, new chi2 = 1.51168494016
# chi2 = 1.51168494016 exceding the limit
# Refitting, new chi2 = 1.51168494016
# chi2 = 1.51168494016 exceding the limit
# Refitting, new chi2 = 6.07222331479
# chi2 = 6.07222331479 exceding the limit
# Refitting, new chi2 = 1.09123882399
# chi2 = 1.09123882399 exceding the limit
# Refitting, new chi2 = 1.091238824
# END phase reached
# fit do not converge on shot 31
# chi2 = 2.10546979485 exceding the limit
# Refitting, new chi2 = 0.374216250527
# chi2 = 3.35181850076 exceding the limit
# Refitting, new chi2 = 0.561559546552
# chi2 = 2.15313246269 exceding the limit
# Refitting, new chi2 = 0.555033201268
# chi2 = 3.58565531768 exceding the limit
# Refitting, new chi2 = 0.962970641271
# chi2 = 2.83908938094 exceding the limit
# Refitting, new chi2 = 0.524701234901
# chi2 = 2.2924979639 exceding the limit
# Refitting, new chi2 = 0.500207524307
# chi2 = 1.44467770906 exceding the limit
# Refitting, new chi2 = 0.662314163122
# chi2 = 1.23917990227 exceding the limit
# Refitting, new chi2 = 1.2391799023
# chi2 = 1.2391799023 exceding the limit
# Refitting, new chi2 = 1.2391799023
# chi2 = 1.2391799023 exceding the limit
# Refitting, new chi2 = 1.23917990226
# chi2 = 1.23917990226 exceding the limit
# Refitting, new chi2 = 2.27720823382
# chi2 = 2.27720823382 exceding the limit
# Refitting, new chi2 = 2.27720823365
# END phase reached
# fit do not converge on shot 62
# chi2 = 1.0609065889 exceding the limit
# Refitting, new chi2 = 1.06090659093
# chi2 = 1.06090659093 exceding the limit
# Refitting, new chi2 = 1.0609065879
# chi2 = 1.0609065879 exceding the limit
# Refitting, new chi2 = 1.0609065886
# chi2 = 1.0609065886 exceding the limit
# Refitting, new chi2 = 1.06090658864
# chi2 = 1.06090658864 exceding the limit
# Refitting, new chi2 = 1.06090658873
# END phase reached
# fit do not converge on shot 72
# chi2 = 1.22316057445 exceding the limit
# Refitting, new chi2 = 1.22316057401
# chi2 = 1.22316057401 exceding the limit
# Refitting, new chi2 = 1.22316057389
# chi2 = 1.22316057389 exceding the limit
# Refitting, new chi2 = 1.22316057453
# chi2 = 1.22316057453 exceding the limit
# Refitting, new chi2 = 1.22316057384
# chi2 = 1.22316057384 exceding the limit
# Refitting, new chi2 = 1.22316057449
# END phase reached
# fit do not converge on shot 109
# chi2 = 1.0792980757 exceding the limit
# Refitting, new chi2 = 1.07929807569
# chi2 = 1.07929807569 exceding the limit
# Refitting, new chi2 = 1.07929807569
# chi2 = 1.07929807569 exceding the limit
# Refitting, new chi2 = 1.07929807569
# chi2 = 1.07929807569 exceding the limit
# Refitting, new chi2 = 1.0792980757
# chi2 = 1.0792980757 exceding the limit
# Refitting, new chi2 = 1.07929807573
# END phase reached
# fit do not converge on shot 123
# chi2 = 1.14829955864 exceding the limit
# Refitting, new chi2 = 1.14829955867
# chi2 = 1.14829955867 exceding the limit
# Refitting, new chi2 = 1.14829955863
# chi2 = 1.14829955863 exceding the limit
# Refitting, new chi2 = 1.14829955864
# chi2 = 1.14829955864 exceding the limit
# Refitting, new chi2 = 1.14829955864
# chi2 = 1.14829955864 exceding the limit
# Refitting, new chi2 = 1.14829955864
# END phase reached
# fit do not converge on shot 124
# chi2 = 1.35865456751 exceding the limit
# Refitting, new chi2 = 1.35865456752
# chi2 = 1.35865456752 exceding the limit
# Refitting, new chi2 = 1.35865456747
# chi2 = 1.35865456747 exceding the limit
# Refitting, new chi2 = 1.35865456763
# chi2 = 1.35865456763 exceding the limit
# Refitting, new chi2 = 1.3586545676
# chi2 = 1.3586545676 exceding the limit
# Refitting, new chi2 = 1.35865456747
# END phase reached
# fit do not converge on shot 127
# chi2 = 1.32758129651 exceding the limit
# Refitting, new chi2 = 1.32758129651
# chi2 = 1.32758129651 exceding the limit
# Refitting, new chi2 = 1.32758129651
# chi2 = 1.32758129651 exceding the limit
# Refitting, new chi2 = 1.32758129655
# chi2 = 1.32758129655 exceding the limit
# Refitting, new chi2 = 1.32758129652
# chi2 = 1.32758129652 exceding the limit
# Refitting, new chi2 = 1.32758129652
# END phase reached
# fit do not converge on shot 128
# PR.BPM23 processed with success 120/129 shots
# chi2 = 1.41148519621 exceding the limit
# Refitting, new chi2 = 1.41148519621
# chi2 = 1.41148519621 exceding the limit
# Refitting, new chi2 = 1.41148519621
# chi2 = 1.41148519621 exceding the limit
# Refitting, new chi2 = 1.41148519621
# chi2 = 1.41148519621 exceding the limit
# Refitting, new chi2 = 13.2254022003
# chi2 = 13.2254022003 exceding the limit
# Refitting, new chi2 = 13.2254022004
# END phase reached
# fit do not converge on shot 2
# chi2 = 1.07732291146 exceding the limit
# Refitting, new chi2 = 1.07732291147
# chi2 = 1.07732291147 exceding the limit
# Refitting, new chi2 = 1.07732291147
# chi2 = 1.07732291147 exceding the limit
# Refitting, new chi2 = 1.07732291147
# chi2 = 1.07732291147 exceding the limit
# Refitting, new chi2 = 12.7026216738
# chi2 = 12.7026216738 exceding the limit
# Refitting, new chi2 = 12.702621673
# END phase reached
# fit do not converge on shot 4
# chi2 = 10.8386531257 exceding the limit
# Refitting, new chi2 = 0.898360605479
# chi2 = 6.64297823202 exceding the limit
# Refitting, new chi2 = 0.721735987583
# chi2 = 1.18005836638 exceding the limit
# Refitting, new chi2 = 1.18005836638
# chi2 = 1.18005836638 exceding the limit
# Refitting, new chi2 = 1.18005836638
# chi2 = 1.18005836638 exceding the limit
# Refitting, new chi2 = 1.18005836638
# chi2 = 1.18005836638 exceding the limit
# Refitting, new chi2 = 7.36854770846
# chi2 = 7.36854770846 exceding the limit
# Refitting, new chi2 = 7.36854770846
# END phase reached
# fit do not converge on shot 26
# chi2 = 1.01611252574 exceding the limit
# Refitting, new chi2 = 1.01611252574
# chi2 = 1.01611252574 exceding the limit
# Refitting, new chi2 = 1.01611252576
# chi2 = 1.01611252576 exceding the limit
# Refitting, new chi2 = 1.01611252574
# chi2 = 1.01611252574 exceding the limit
# Refitting, new chi2 = 1.01611252574
# chi2 = 1.01611252574 exceding the limit
# Refitting, new chi2 = 3.21461220742
# END phase reached
# fit do not converge on shot 59
# chi2 = 1.16372935492 exceding the limit
# Refitting, new chi2 = 1.16372935414
# chi2 = 1.16372935414 exceding the limit
# Refitting, new chi2 = 1.16372935611
# chi2 = 1.16372935611 exceding the limit
# Refitting, new chi2 = 1.16372935283
# chi2 = 1.16372935283 exceding the limit
# Refitting, new chi2 = 1.16372935468
# chi2 = 1.16372935468 exceding the limit
# Refitting, new chi2 = 1.16372935316
# END phase reached
# fit do not converge on shot 66
# chi2 = 1.19661934484 exceding the limit
# Refitting, new chi2 = 1.19661934598
# chi2 = 1.19661934598 exceding the limit
# Refitting, new chi2 = 1.19661934429
# chi2 = 1.19661934429 exceding the limit
# Refitting, new chi2 = 1.1966193488
# chi2 = 1.1966193488 exceding the limit
# Refitting, new chi2 = 1.19661934587
# chi2 = 1.19661934587 exceding the limit
# Refitting, new chi2 = 1.19661934661
# END phase reached
# fit do not converge on shot 73
# chi2 = 1.21724087384 exceding the limit
# Refitting, new chi2 = 1.21724087383
# chi2 = 1.21724087383 exceding the limit
# Refitting, new chi2 = 1.21724087344
# chi2 = 1.21724087344 exceding the limit
# Refitting, new chi2 = 1.21724087354
# chi2 = 1.21724087354 exceding the limit
# Refitting, new chi2 = 1.2172408734
# chi2 = 1.2172408734 exceding the limit
# Refitting, new chi2 = 1.21724087341
# END phase reached
# fit do not converge on shot 98
# chi2 = 1.18670530867 exceding the limit
# Refitting, new chi2 = 1.18670530879
# chi2 = 1.18670530879 exceding the limit
# Refitting, new chi2 = 1.18670530867
# chi2 = 1.18670530867 exceding the limit
# Refitting, new chi2 = 1.18670530866
# chi2 = 1.18670530866 exceding the limit
# Refitting, new chi2 = 1.1867053088
# chi2 = 1.1867053088 exceding the limit
# Refitting, new chi2 = 1.1867053087
# END phase reached
# fit do not converge on shot 112
# chi2 = 1.01093207385 exceding the limit
# Refitting, new chi2 = 1.01093207386
# chi2 = 1.01093207386 exceding the limit
# Refitting, new chi2 = 1.01093207384
# chi2 = 1.01093207384 exceding the limit
# Refitting, new chi2 = 1.01093207386
# chi2 = 1.01093207386 exceding the limit
# Refitting, new chi2 = 1.01093207384
# chi2 = 1.01093207384 exceding the limit
# Refitting, new chi2 = 1.01093207388
# END phase reached
# fit do not converge on shot 120
# chi2 = 1.26066620053 exceding the limit
# Refitting, new chi2 = 1.26066620052
# chi2 = 1.26066620052 exceding the limit
# Refitting, new chi2 = 1.26066620057
# chi2 = 1.26066620057 exceding the limit
# Refitting, new chi2 = 1.26066620052
# chi2 = 1.26066620052 exceding the limit
# Refitting, new chi2 = 1.26066620048
# chi2 = 1.26066620048 exceding the limit
# Refitting, new chi2 = 1.2606662005
# END phase reached
# fit do not converge on shot 124
# chi2 = 1.46880099548 exceding the limit
# Refitting, new chi2 = 1.46880099548
# chi2 = 1.46880099548 exceding the limit
# Refitting, new chi2 = 1.46880099548
# chi2 = 1.46880099548 exceding the limit
# Refitting, new chi2 = 1.46880099548
# chi2 = 1.46880099548 exceding the limit
# Refitting, new chi2 = 1.46880099548
# chi2 = 1.46880099548 exceding the limit
# Refitting, new chi2 = 1.46880099548
# END phase reached
# fit do not converge on shot 128
# PR.BPM25 processed with success 118/129 shots
# chi2 = 1.0899754045 exceding the limit
# Refitting, new chi2 = 1.08997540454
# chi2 = 1.08997540454 exceding the limit
# Refitting, new chi2 = 1.08997540445
# chi2 = 1.08997540445 exceding the limit
# Refitting, new chi2 = 1.08997540458
# chi2 = 1.08997540458 exceding the limit
# Refitting, new chi2 = 1.08997540447
# chi2 = 1.08997540447 exceding the limit
# Refitting, new chi2 = 1.08997540465
# END phase reached
# fit do not converge on shot 2
# chi2 = 1.27334204233 exceding the limit
# Refitting, new chi2 = 1.7895298795
# chi2 = 1.7895298795 exceding the limit
# Refitting, new chi2 = 1.27334204234
# chi2 = 1.27334204234 exceding the limit
# Refitting, new chi2 = 1.27334204238
# chi2 = 1.27334204238 exceding the limit
# Refitting, new chi2 = 1.2733420425
# chi2 = 1.2733420425 exceding the limit
# Refitting, new chi2 = 1.27334204236
# END phase reached
# fit do not converge on shot 63
# chi2 = 1.1467588711 exceding the limit
# Refitting, new chi2 = 1.14675886947
# chi2 = 1.14675886947 exceding the limit
# Refitting, new chi2 = 1.14675887142
# chi2 = 1.14675887142 exceding the limit
# Refitting, new chi2 = 1.14675887065
# chi2 = 1.14675887065 exceding the limit
# Refitting, new chi2 = 1.14675886956
# chi2 = 1.14675886956 exceding the limit
# Refitting, new chi2 = 1.14675886972
# END phase reached
# fit do not converge on shot 71
# chi2 = 1.14975748664 exceding the limit
# Refitting, new chi2 = 1.14975748645
# chi2 = 1.14975748645 exceding the limit
# Refitting, new chi2 = 1.14975748657
# chi2 = 1.14975748657 exceding the limit
# Refitting, new chi2 = 1.14975748652
# chi2 = 1.14975748652 exceding the limit
# Refitting, new chi2 = 1.14975748647
# chi2 = 1.14975748647 exceding the limit
# Refitting, new chi2 = 1.1497574866
# END phase reached
# fit do not converge on shot 72
# chi2 = 1.12976442389 exceding the limit
# Refitting, new chi2 = 1.12976442382
# chi2 = 1.12976442382 exceding the limit
# Refitting, new chi2 = 1.12976442384
# chi2 = 1.12976442384 exceding the limit
# Refitting, new chi2 = 1.12976442386
# chi2 = 1.12976442386 exceding the limit
# Refitting, new chi2 = 1.12976442376
# chi2 = 1.12976442376 exceding the limit
# Refitting, new chi2 = 1.1297644238
# END phase reached
# fit do not converge on shot 77
# chi2 = 1.01548985023 exceding the limit
# Refitting, new chi2 = 1.01548985105
# chi2 = 1.01548985105 exceding the limit
# Refitting, new chi2 = 1.01548984977
# chi2 = 1.01548984977 exceding the limit
# Refitting, new chi2 = 1.01548985069
# chi2 = 1.01548985069 exceding the limit
# Refitting, new chi2 = 1.01548985008
# chi2 = 1.01548985008 exceding the limit
# Refitting, new chi2 = 1.01548984967
# END phase reached
# fit do not converge on shot 82
# chi2 = 1.10982079473 exceding the limit
# Refitting, new chi2 = 1.10982079475
# chi2 = 1.10982079475 exceding the limit
# Refitting, new chi2 = 1.10982079471
# chi2 = 1.10982079471 exceding the limit
# Refitting, new chi2 = 1.10982079463
# chi2 = 1.10982079463 exceding the limit
# Refitting, new chi2 = 1.10982079493
# chi2 = 1.10982079493 exceding the limit
# Refitting, new chi2 = 1.10982079486
# END phase reached
# fit do not converge on shot 91
# chi2 = 1.07152766278 exceding the limit
# Refitting, new chi2 = 1.07152766267
# chi2 = 1.07152766267 exceding the limit
# Refitting, new chi2 = 1.07152766266
# chi2 = 1.07152766266 exceding the limit
# Refitting, new chi2 = 1.07152766268
# chi2 = 1.07152766268 exceding the limit
# Refitting, new chi2 = 1.07152766267
# chi2 = 1.07152766267 exceding the limit
# Refitting, new chi2 = 1.07152766267
# END phase reached
# fit do not converge on shot 94
# chi2 = 1.15119007557 exceding the limit
# Refitting, new chi2 = 1.15119007678
# chi2 = 1.15119007678 exceding the limit
# Refitting, new chi2 = 1.15119007482
# chi2 = 1.15119007482 exceding the limit
# Refitting, new chi2 = 1.15119007547
# chi2 = 1.15119007547 exceding the limit
# Refitting, new chi2 = 1.15119007671
# chi2 = 1.15119007671 exceding the limit
# Refitting, new chi2 = 1.15119007598
# END phase reached
# fit do not converge on shot 99
# chi2 = 1.04384438785 exceding the limit
# Refitting, new chi2 = 1.04384438784
# chi2 = 1.04384438784 exceding the limit
# Refitting, new chi2 = 1.04384438788
# chi2 = 1.04384438788 exceding the limit
# Refitting, new chi2 = 1.0438443879
# chi2 = 1.0438443879 exceding the limit
# Refitting, new chi2 = 1.04384438785
# chi2 = 1.04384438785 exceding the limit
# Refitting, new chi2 = 1.04384438784
# END phase reached
# fit do not converge on shot 117
# chi2 = 1.02060115785 exceding the limit
# Refitting, new chi2 = 1.02060115785
# chi2 = 1.02060115785 exceding the limit
# Refitting, new chi2 = 1.02060115796
# chi2 = 1.02060115796 exceding the limit
# Refitting, new chi2 = 1.02060115792
# chi2 = 1.02060115792 exceding the limit
# Refitting, new chi2 = 1.02060115784
# chi2 = 1.02060115784 exceding the limit
# Refitting, new chi2 = 1.02060115781
# END phase reached
# fit do not converge on shot 119
# chi2 = 1.00018330349 exceding the limit
# Refitting, new chi2 = 1.00018330349
# chi2 = 1.00018330349 exceding the limit
# Refitting, new chi2 = 1.00018330349
# chi2 = 1.00018330349 exceding the limit
# Refitting, new chi2 = 1.00018330349
# chi2 = 1.00018330349 exceding the limit
# Refitting, new chi2 = 1.00018330349
# chi2 = 1.00018330349 exceding the limit
# Refitting, new chi2 = 1.00018330349
# END phase reached
# fit do not converge on shot 124
# PR.BPM27 processed with success 117/129 shots
# chi2 = 1.11785178453 exceding the limit
# Refitting, new chi2 = 1.11785178459
# chi2 = 1.11785178459 exceding the limit
# Refitting, new chi2 = 1.11785178453
# chi2 = 1.11785178453 exceding the limit
# Refitting, new chi2 = 1.11785178453
# chi2 = 1.11785178453 exceding the limit
# Refitting, new chi2 = 1.11785178455
# chi2 = 1.11785178455 exceding the limit
# Refitting, new chi2 = 1.11785178453
# END phase reached
# fit do not converge on shot 8
# chi2 = 1.01560665497 exceding the limit
# Refitting, new chi2 = 1.01560665497
# chi2 = 1.01560665497 exceding the limit
# Refitting, new chi2 = 1.01560665497
# chi2 = 1.01560665497 exceding the limit
# Refitting, new chi2 = 1.01560665497
# chi2 = 1.01560665497 exceding the limit
# Refitting, new chi2 = 1.01560665497
# chi2 = 1.01560665497 exceding the limit
# Refitting, new chi2 = 1.01560665496
# END phase reached
# fit do not converge on shot 27
# chi2 = 1.14924338639 exceding the limit
# Refitting, new chi2 = 1.14924338636
# chi2 = 1.14924338636 exceding the limit
# Refitting, new chi2 = 1.14924338636
# chi2 = 1.14924338636 exceding the limit
# Refitting, new chi2 = 1.14924338647
# chi2 = 1.14924338647 exceding the limit
# Refitting, new chi2 = 1.14924338644
# chi2 = 1.14924338644 exceding the limit
# Refitting, new chi2 = 1.14924338637
# END phase reached
# fit do not converge on shot 32
# chi2 = 1.353212753 exceding the limit
# Refitting, new chi2 = 1.35321275275
# chi2 = 1.35321275275 exceding the limit
# Refitting, new chi2 = 1.35321275297
# chi2 = 1.35321275297 exceding the limit
# Refitting, new chi2 = 1.353212753
# chi2 = 1.353212753 exceding the limit
# Refitting, new chi2 = 1.35321275236
# chi2 = 1.35321275236 exceding the limit
# Refitting, new chi2 = 1.3532127527
# END phase reached
# fit do not converge on shot 65
# chi2 = 1.0376786492 exceding the limit
# Refitting, new chi2 = 1.03767865061
# chi2 = 1.03767865061 exceding the limit
# Refitting, new chi2 = 1.03767864822
# chi2 = 1.03767864822 exceding the limit
# Refitting, new chi2 = 1.03767864744
# chi2 = 1.03767864744 exceding the limit
# Refitting, new chi2 = 1.03767865319
# chi2 = 1.03767865319 exceding the limit
# Refitting, new chi2 = 1.03767865175
# END phase reached
# fit do not converge on shot 70
# chi2 = 1.24115900257 exceding the limit
# Refitting, new chi2 = 1.24115900226
# chi2 = 1.24115900226 exceding the limit
# Refitting, new chi2 = 1.24115900248
# chi2 = 1.24115900248 exceding the limit
# Refitting, new chi2 = 1.24115900215
# chi2 = 1.24115900215 exceding the limit
# Refitting, new chi2 = 1.24115900219
# chi2 = 1.24115900219 exceding the limit
# Refitting, new chi2 = 1.24115900226
# END phase reached
# fit do not converge on shot 72
# chi2 = 1.00666140693 exceding the limit
# Refitting, new chi2 = 0.90392584655
# chi2 = 1.41740801461 exceding the limit
# Refitting, new chi2 = 3.54634582451
# chi2 = 3.54634582451 exceding the limit
# Refitting, new chi2 = 1.41740801485
# chi2 = 1.41740801485 exceding the limit
# Refitting, new chi2 = 1.41740801467
# chi2 = 1.41740801467 exceding the limit
# Refitting, new chi2 = 1.41740801462
# chi2 = 1.41740801462 exceding the limit
# Refitting, new chi2 = 1.41740801511
# END phase reached
# fit do not converge on shot 91
# chi2 = 1.21404654645 exceding the limit
# Refitting, new chi2 = 2.34887925513
# chi2 = 2.34887925513 exceding the limit
# Refitting, new chi2 = 2.34887925513
# chi2 = 2.34887925513 exceding the limit
# Refitting, new chi2 = 1.21404654658
# chi2 = 1.21404654658 exceding the limit
# Refitting, new chi2 = 1.21404654663
# chi2 = 1.21404654663 exceding the limit
# Refitting, new chi2 = 1.21404654651
# END phase reached
# fit do not converge on shot 103
# chi2 = 1.3166678253 exceding the limit
# Refitting, new chi2 = 2.44062947478
# chi2 = 2.44062947478 exceding the limit
# Refitting, new chi2 = 2.4406294738
# chi2 = 2.4406294738 exceding the limit
# Refitting, new chi2 = 1.3166678253
# chi2 = 1.3166678253 exceding the limit
# Refitting, new chi2 = 1.3166678253
# chi2 = 1.3166678253 exceding the limit
# Refitting, new chi2 = 1.3166678253
# END phase reached
# fit do not converge on shot 106
# chi2 = 1.16605537141 exceding the limit
# Refitting, new chi2 = 2.38023431731
# chi2 = 2.38023431731 exceding the limit
# Refitting, new chi2 = 2.38023431731
# chi2 = 2.38023431731 exceding the limit
# Refitting, new chi2 = 1.16605537121
# chi2 = 1.16605537121 exceding the limit
# Refitting, new chi2 = 1.16605537138
# chi2 = 1.16605537138 exceding the limit
# Refitting, new chi2 = 1.16605537122
# END phase reached
# fit do not converge on shot 109
# chi2 = 1.21897457589 exceding the limit
# Refitting, new chi2 = 5.27957308045
# chi2 = 5.27957308045 exceding the limit
# Refitting, new chi2 = 1.21897457579
# chi2 = 1.21897457579 exceding the limit
# Refitting, new chi2 = 1.21897457582
# chi2 = 1.21897457582 exceding the limit
# Refitting, new chi2 = 1.21897457615
# chi2 = 1.21897457615 exceding the limit
# Refitting, new chi2 = 1.21897457581
# END phase reached
# fit do not converge on shot 124
# PR.BPM30 processed with success 118/129 shots
# chi2 = 1.02231196888 exceding the limit
# Refitting, new chi2 = 1.02231196888
# chi2 = 1.02231196888 exceding the limit
# Refitting, new chi2 = 1.02231196888
# chi2 = 1.02231196888 exceding the limit
# Refitting, new chi2 = 1.02231196888
# chi2 = 1.02231196888 exceding the limit
# Refitting, new chi2 = 1.02231196888
# chi2 = 1.02231196888 exceding the limit
# Refitting, new chi2 = 1.02231196891
# END phase reached
# fit do not converge on shot 24
# chi2 = 1.17243235215 exceding the limit
# Refitting, new chi2 = 1.17243235213
# chi2 = 1.17243235213 exceding the limit
# Refitting, new chi2 = 1.17243235229
# chi2 = 1.17243235229 exceding the limit
# Refitting, new chi2 = 1.17243235212
# chi2 = 1.17243235212 exceding the limit
# Refitting, new chi2 = 1.17243235228
# chi2 = 1.17243235228 exceding the limit
# Refitting, new chi2 = 1.17243235216
# END phase reached
# fit do not converge on shot 25
# chi2 = 1.08875533501 exceding the limit
# Refitting, new chi2 = 1.08875533499
# chi2 = 1.08875533499 exceding the limit
# Refitting, new chi2 = 1.08875533502
# chi2 = 1.08875533502 exceding the limit
# Refitting, new chi2 = 1.08875533511
# chi2 = 1.08875533511 exceding the limit
# Refitting, new chi2 = 1.08875533502
# chi2 = 1.08875533502 exceding the limit
# Refitting, new chi2 = 1.08875533497
# END phase reached
# fit do not converge on shot 26
# chi2 = 1.1590994802 exceding the limit
# Refitting, new chi2 = 1.1590994802
# chi2 = 1.1590994802 exceding the limit
# Refitting, new chi2 = 1.15909948022
# chi2 = 1.15909948022 exceding the limit
# Refitting, new chi2 = 1.1590994802
# chi2 = 1.1590994802 exceding the limit
# Refitting, new chi2 = 1.15909948022
# chi2 = 1.15909948022 exceding the limit
# Refitting, new chi2 = 1.1590994802
# END phase reached
# fit do not converge on shot 28
# chi2 = 1.22234250682 exceding the limit
# Refitting, new chi2 = 1.22234250681
# chi2 = 1.22234250681 exceding the limit
# Refitting, new chi2 = 1.22234250682
# chi2 = 1.22234250682 exceding the limit
# Refitting, new chi2 = 1.22234250702
# chi2 = 1.22234250702 exceding the limit
# Refitting, new chi2 = 1.22234250692
# chi2 = 1.22234250692 exceding the limit
# Refitting, new chi2 = 1.22234250681
# END phase reached
# fit do not converge on shot 33
# chi2 = 1.37813656234 exceding the limit
# Refitting, new chi2 = 1.3781365625
# chi2 = 1.3781365625 exceding the limit
# Refitting, new chi2 = 1.37813656234
# chi2 = 1.37813656234 exceding the limit
# Refitting, new chi2 = 1.37813656236
# chi2 = 1.37813656236 exceding the limit
# Refitting, new chi2 = 1.37813656237
# chi2 = 1.37813656237 exceding the limit
# Refitting, new chi2 = 1.37813656236
# END phase reached
# fit do not converge on shot 34
# chi2 = 1.14582024906 exceding the limit
# Refitting, new chi2 = 1.14582024905
# chi2 = 1.14582024905 exceding the limit
# Refitting, new chi2 = 1.14582024906
# chi2 = 1.14582024906 exceding the limit
# Refitting, new chi2 = 1.14582024906
# chi2 = 1.14582024906 exceding the limit
# Refitting, new chi2 = 1.14582024905
# chi2 = 1.14582024905 exceding the limit
# Refitting, new chi2 = 1.14582024906
# END phase reached
# fit do not converge on shot 38
# chi2 = 1.29658306496 exceding the limit
# Refitting, new chi2 = 1.29658306586
# chi2 = 1.29658306586 exceding the limit
# Refitting, new chi2 = 1.29658306486
# chi2 = 1.29658306486 exceding the limit
# Refitting, new chi2 = 1.29658306492
# chi2 = 1.29658306492 exceding the limit
# Refitting, new chi2 = 1.29658306467
# chi2 = 1.29658306467 exceding the limit
# Refitting, new chi2 = 1.29658306463
# END phase reached
# fit do not converge on shot 41
# chi2 = 1.11095408638 exceding the limit
# Refitting, new chi2 = 1.11095408643
# chi2 = 1.11095408643 exceding the limit
# Refitting, new chi2 = 1.11095408637
# chi2 = 1.11095408637 exceding the limit
# Refitting, new chi2 = 1.11095408638
# chi2 = 1.11095408638 exceding the limit
# Refitting, new chi2 = 1.11095408637
# chi2 = 1.11095408637 exceding the limit
# Refitting, new chi2 = 1.11095408639
# END phase reached
# fit do not converge on shot 51
# chi2 = 1.13439213834 exceding the limit
# Refitting, new chi2 = 1.13439213834
# chi2 = 1.13439213834 exceding the limit
# ...
# Refitting, new chi2 = 8.45980868091
# END phase reached
# fit do not converge on shot 113
# chi2 = 7.68394948082 exceding the limit
# Refitting, new chi2 = 1.67636077511
# chi2 = 1.67636077511 exceding the limit
# Refitting, new chi2 = 1.67636077511
# chi2 = 1.67636077511 exceding the limit
# Refitting, new chi2 = 1.67636077511
# chi2 = 1.67636077511 exceding the limit
# Refitting, new chi2 = 0.544157045902
# chi2 = 6.0867290784 exceding the limit
# Refitting, new chi2 = 1.15291009702
# chi2 = 1.15291009702 exceding the limit
# Refitting, new chi2 = 1.15291009701
# chi2 = 1.15291009701 exceding the limit
# Refitting, new chi2 = 6.67727860502
# chi2 = 6.67727860502 exceding the limit
# Refitting, new chi2 = 6.67727861024
# chi2 = 6.67727861024 exceding the limit
# Refitting, new chi2 = 0.479082973775
# END phase reached
# fit do not converge on shot 115
# chi2 = 6.94572145595 exceding the limit
# Refitting, new chi2 = 1.14104975715
# chi2 = 1.14104975715 exceding the limit
# Refitting, new chi2 = 1.14104975715
# chi2 = 1.14104975715 exceding the limit
# Refitting, new chi2 = 1.14104975715
# chi2 = 1.14104975715 exceding the limit
# Refitting, new chi2 = 7.70558523968
# chi2 = 7.70558523968 exceding the limit
# Refitting, new chi2 = 0.412482056766
# END phase reached
# fit do not converge on shot 116
# chi2 = 9.81837758502 exceding the limit
# Refitting, new chi2 = 1.51245343966
# chi2 = 1.51245343966 exceding the limit
# Refitting, new chi2 = 1.51245343966
# chi2 = 1.51245343966 exceding the limit
# Refitting, new chi2 = 1.51245343966
# chi2 = 1.51245343966 exceding the limit
# Refitting, new chi2 = 10.4248303661
# chi2 = 10.4248303661 exceding the limit
# Refitting, new chi2 = 0.412336645179
# END phase reached
# fit do not converge on shot 117
# chi2 = 9.73995385675 exceding the limit
# Refitting, new chi2 = 1.31264809898
# chi2 = 1.31264809898 exceding the limit
# Refitting, new chi2 = 1.31264809898
# chi2 = 1.31264809898 exceding the limit
# Refitting, new chi2 = 10.2631814073
# chi2 = 10.2631814073 exceding the limit
# Refitting, new chi2 = 10.2631814072
# chi2 = 10.2631814072 exceding the limit
# Refitting, new chi2 = 0.542366007844
# END phase reached
# fit do not converge on shot 118
# chi2 = 8.36287438817 exceding the limit
# Refitting, new chi2 = 1.34049611703
# chi2 = 1.34049611703 exceding the limit
# Refitting, new chi2 = 1.34049611703
# chi2 = 1.34049611703 exceding the limit
# Refitting, new chi2 = 1.34049611703
# chi2 = 1.34049611703 exceding the limit
# Refitting, new chi2 = 9.22593929611
# chi2 = 9.22593929611 exceding the limit
# Refitting, new chi2 = 0.524624483906
# END phase reached
# fit do not converge on shot 119
# chi2 = 10.9016922713 exceding the limit
# Refitting, new chi2 = 1.65186449899
# chi2 = 1.65186449899 exceding the limit
# Refitting, new chi2 = 1.65186449895
# chi2 = 1.65186449895 exceding the limit
# Refitting, new chi2 = 12.2183355211
# chi2 = 12.2183355211 exceding the limit
# Refitting, new chi2 = 12.2183355133
# chi2 = 12.2183355133 exceding the limit
# Refitting, new chi2 = 0.403916738154
# END phase reached
# fit do not converge on shot 120
# chi2 = 10.0028201011 exceding the limit
# Refitting, new chi2 = 1.2713685456
# chi2 = 1.2713685456 exceding the limit
# Refitting, new chi2 = 1.2713685456
# chi2 = 1.2713685456 exceding the limit
# Refitting, new chi2 = 11.032391803
# chi2 = 11.032391803 exceding the limit
# Refitting, new chi2 = 11.0323918023
# chi2 = 11.0323918023 exceding the limit
# Refitting, new chi2 = 0.398687663781
# END phase reached
# fit do not converge on shot 121
# chi2 = 10.908761523 exceding the limit
# Refitting, new chi2 = 1.331986204
# chi2 = 1.331986204 exceding the limit
# Refitting, new chi2 = 1.331986204
# chi2 = 1.331986204 exceding the limit
# Refitting, new chi2 = 1.331986204
# chi2 = 1.331986204 exceding the limit
# Refitting, new chi2 = 11.4423117198
# chi2 = 11.4423117198 exceding the limit
# Refitting, new chi2 = 0.454384108293
# END phase reached
# fit do not converge on shot 122
# chi2 = 10.6728952905 exceding the limit
# Refitting, new chi2 = 1.99174310576
# chi2 = 1.99174310576 exceding the limit
# Refitting, new chi2 = 1.99174310576
# chi2 = 1.99174310576 exceding the limit
# Refitting, new chi2 = 1.99174310576
# chi2 = 1.99174310576 exceding the limit
# Refitting, new chi2 = 12.1742622768
# chi2 = 12.1742622768 exceding the limit
# Refitting, new chi2 = 0.513846650451
# END phase reached
# fit do not converge on shot 125
# PR.BPM67 processed with success 113/129 shots
# chi2 = 1.96441177155 exceding the limit
# Refitting, new chi2 = 0.746794641369
# chi2 = 1.67309002291 exceding the limit
# Refitting, new chi2 = 0.497513523221
# chi2 = 1.77433249134 exceding the limit
# Refitting, new chi2 = 0.393423949779
# chi2 = 3.10091504062 exceding the limit
# Refitting, new chi2 = 0.728209242166
# chi2 = 3.15730434206 exceding the limit
# Refitting, new chi2 = 0.618245673694
# chi2 = 2.58340861111 exceding the limit
# Refitting, new chi2 = 0.446792000958
# chi2 = 2.70422663842 exceding the limit
# Refitting, new chi2 = 0.631534985897
# chi2 = 1.96062597287 exceding the limit
# Refitting, new chi2 = 0.535215521141
# chi2 = 3.27833678099 exceding the limit
# Refitting, new chi2 = 0.669810198189
# chi2 = 2.95924293884 exceding the limit
# Refitting, new chi2 = 0.507354041114
# chi2 = 3.19515943859 exceding the limit
# Refitting, new chi2 = 0.364157796442
# chi2 = 4.51188287759 exceding the limit
# Refitting, new chi2 = 0.720343216336
# chi2 = 4.13377171057 exceding the limit
# Refitting, new chi2 = 0.504246510337
# chi2 = 4.17267039421 exceding the limit
# Refitting, new chi2 = 0.746139603397
# chi2 = 5.60387826474 exceding the limit
# Refitting, new chi2 = 0.72156317317
# chi2 = 3.98139061223 exceding the limit
# Refitting, new chi2 = 0.327496450812
# chi2 = 4.05630656702 exceding the limit
# Refitting, new chi2 = 0.624941671322
# chi2 = 4.6280842927 exceding the limit
# Refitting, new chi2 = 0.776132057317
# chi2 = 4.66613364147 exceding the limit
# Refitting, new chi2 = 0.631614450295
# chi2 = 5.80342211363 exceding the limit
# Refitting, new chi2 = 0.629001821223
# chi2 = 6.24094474089 exceding the limit
# Refitting, new chi2 = 0.481514340187
# chi2 = 4.83695299297 exceding the limit
# Refitting, new chi2 = 0.522907701431
# chi2 = 5.09255021287 exceding the limit
# Refitting, new chi2 = 0.870944711624
# chi2 = 5.16856162108 exceding the limit
# Refitting, new chi2 = 0.680916259265
# chi2 = 6.58852897287 exceding the limit
# Refitting, new chi2 = 0.528257179473
# chi2 = 5.88707746476 exceding the limit
# Refitting, new chi2 = 0.499831056752
# chi2 = 6.36074800273 exceding the limit
# Refitting, new chi2 = 0.726195273064
# chi2 = 5.8415497831 exceding the limit
# Refitting, new chi2 = 0.712284280667
# PR.BPM68 processed with success 129/129 shots
# chi2 = 1.02587639842 exceding the limit
# Refitting, new chi2 = 0.518216751307
# chi2 = 1.34074163595 exceding the limit
# Refitting, new chi2 = 0.391961359255
# PR.BPM70 processed with success 129/129 shots
# chi2 = 1.91120464967 exceding the limit
# Refitting, new chi2 = 0.351666829671
# PR.BPM73 processed with success 129/129 shots
# chi2 = 3.78616316478 exceding the limit
# Refitting, new chi2 = 0.925371045055
# chi2 = 3.01620443487 exceding the limit
# Refitting, new chi2 = 0.369507522913
# chi2 = 2.11114752369 exceding the limit
# Refitting, new chi2 = 0.37604970914
# chi2 = 1.21980937306 exceding the limit
# Refitting, new chi2 = 0.256874746663
# chi2 = 3.7878991416 exceding the limit
# Refitting, new chi2 = 0.392225399486
# chi2 = 2.64877630598 exceding the limit
# Refitting, new chi2 = 0.230313492289
# chi2 = 1.794146561 exceding the limit
# Refitting, new chi2 = 0.394456247992
# PR.BPM75 processed with success 129/129 shots
# PR.BPM77 processed with success 129/129 shots
# PR.BPM80 processed with success 129/129 shots
# chi2 = 2.69681015188 exceding the limit
# Refitting, new chi2 = 0.999137856324
# chi2 = 2.92368245528 exceding the limit
# Refitting, new chi2 = 0.733447672719
# chi2 = 3.10086847691 exceding the limit
# Refitting, new chi2 = 0.583910088379
# chi2 = 3.47001008568 exceding the limit
# Refitting, new chi2 = 0.795571065954
# chi2 = 4.30550475974 exceding the limit
# Refitting, new chi2 = 0.875518819343
# chi2 = 5.59586207045 exceding the limit
# Refitting, new chi2 = 0.899594114679
# chi2 = 6.19191427509 exceding the limit
# Refitting, new chi2 = 0.984207483954
# chi2 = 4.82947604955 exceding the limit
# Refitting, new chi2 = 1.32329674256
# chi2 = 1.32329674256 exceding the limit
# Refitting, new chi2 = 1.32329674256
# chi2 = 1.32329674256 exceding the limit
# Refitting, new chi2 = 1.32329674256
# chi2 = 1.32329674256 exceding the limit
# Refitting, new chi2 = 4.99790415172
# chi2 = 4.99790415172 exceding the limit
# Refitting, new chi2 = 0.576447801317
# END phase reached
# fit do not converge on shot 103
# chi2 = 4.69088528954 exceding the limit
# Refitting, new chi2 = 1.26186638951
# chi2 = 1.26186638951 exceding the limit
# Refitting, new chi2 = 1.26186638953
# chi2 = 1.26186638953 exceding the limit
# Refitting, new chi2 = 1.26186638961
# chi2 = 1.26186638961 exceding the limit
# Refitting, new chi2 = 5.35125661342
# chi2 = 5.35125661342 exceding the limit
# Refitting, new chi2 = 0.431386262513
# END phase reached
# fit do not converge on shot 104
# chi2 = 3.83792411671 exceding the limit
# Refitting, new chi2 = 0.877008740513
# chi2 = 4.30381394258 exceding the limit
# Refitting, new chi2 = 1.05013648745
# chi2 = 1.05013648745 exceding the limit
# Refitting, new chi2 = 1.05013648745
# chi2 = 1.05013648745 exceding the limit
# Refitting, new chi2 = 4.75088646884
# chi2 = 4.75088646884 exceding the limit
# Refitting, new chi2 = 4.75088646884
# chi2 = 4.75088646884 exceding the limit
# Refitting, new chi2 = 4.75088646884
# END phase reached
# fit do not converge on shot 106
# chi2 = 4.27151240576 exceding the limit
# Refitting, new chi2 = 0.87751085096
# chi2 = 4.88853189373 exceding the limit
# Refitting, new chi2 = 1.04504083032
# chi2 = 1.04504083032 exceding the limit
# Refitting, new chi2 = 1.04504083032
# chi2 = 1.04504083032 exceding the limit
# Refitting, new chi2 = 1.04504083032
# chi2 = 1.04504083032 exceding the limit
# Refitting, new chi2 = 5.52883358283
# chi2 = 5.52883358283 exceding the limit
# Refitting, new chi2 = 0.283746334245
# END phase reached
# fit do not converge on shot 108
# chi2 = 6.1361760678 exceding the limit
# Refitting, new chi2 = 1.23865384161
# chi2 = 1.23865384161 exceding the limit
# Refitting, new chi2 = 1.23865384161
# chi2 = 1.23865384161 exceding the limit
# Refitting, new chi2 = 1.23865384161
# chi2 = 1.23865384161 exceding the limit
# Refitting, new chi2 = 7.07055249768
# chi2 = 7.07055249768 exceding the limit
# Refitting, new chi2 = 0.555073028281
# END phase reached
# fit do not converge on shot 109
# chi2 = 6.13118510574 exceding the limit
# Refitting, new chi2 = 1.09207429537
# chi2 = 1.09207429537 exceding the limit
# Refitting, new chi2 = 1.09207429537
# chi2 = 1.09207429537 exceding the limit
# Refitting, new chi2 = 6.41673139894
# chi2 = 6.41673139894 exceding the limit
# Refitting, new chi2 = 6.41673139873
# chi2 = 6.41673139873 exceding the limit
# Refitting, new chi2 = 0.537767803089
# END phase reached
# fit do not converge on shot 110
# chi2 = 6.8584042687 exceding the limit
# Refitting, new chi2 = 1.41846509134
# chi2 = 1.41846509134 exceding the limit
# Refitting, new chi2 = 1.41846509134
# chi2 = 1.41846509134 exceding the limit
# Refitting, new chi2 = 1.41846509134
# chi2 = 1.41846509134 exceding the limit
# Refitting, new chi2 = 7.38004340649
# chi2 = 7.38004340649 exceding the limit
# Refitting, new chi2 = 0.581589321517
# END phase reached
# fit do not converge on shot 112
# chi2 = 7.53453013493 exceding the limit
# Refitting, new chi2 = 1.86861696641
# chi2 = 1.86861696641 exceding the limit
# Refitting, new chi2 = 1.86861696633
# chi2 = 1.86861696633 exceding the limit
# Refitting, new chi2 = 8.18569278924
# chi2 = 8.18569278924 exceding the limit
# Refitting, new chi2 = 0.576005764334
# chi2 = 7.8995267121 exceding the limit
# Refitting, new chi2 = 1.33659242188
# chi2 = 1.33659242188 exceding the limit
# Refitting, new chi2 = 1.33659242188
# chi2 = 1.33659242188 exceding the limit
# Refitting, new chi2 = 1.33659242188
# chi2 = 1.33659242188 exceding the limit
# Refitting, new chi2 = 8.85180511854
# chi2 = 8.85180511854 exceding the limit
# Refitting, new chi2 = 0.414622742678
# END phase reached
# fit do not converge on shot 117
# chi2 = 9.39359635464 exceding the limit
# Refitting, new chi2 = 1.88232367084
# chi2 = 1.88232367084 exceding the limit
# Refitting, new chi2 = 1.88232367084
# chi2 = 1.88232367084 exceding the limit
# Refitting, new chi2 = 11.0080606998
# chi2 = 11.0080606998 exceding the limit
# Refitting, new chi2 = 0.342819795159
# chi2 = 9.36349244991 exceding the limit
# Refitting, new chi2 = 2.3173343378
# chi2 = 2.3173343378 exceding the limit
# Refitting, new chi2 = 2.31733433772
# chi2 = 2.31733433772 exceding the limit
# Refitting, new chi2 = 10.4133885314
# chi2 = 10.4133885314 exceding the limit
# Refitting, new chi2 = 0.362609197066
# chi2 = 10.0629761313 exceding the limit
# Refitting, new chi2 = 2.27660251487
# chi2 = 2.27660251487 exceding the limit
# Refitting, new chi2 = 2.27660251482
# chi2 = 2.27660251482 exceding the limit
# Refitting, new chi2 = 11.485750885
# chi2 = 11.485750885 exceding the limit
# Refitting, new chi2 = 0.330320957658
# PR.BPM83 processed with success 121/129 shots
# chi2 = 1.25852858947 exceding the limit
# Refitting, new chi2 = 0.368275921744
# chi2 = 1.83350713004 exceding the limit
# Refitting, new chi2 = 0.382534367178
# chi2 = 1.73788428662 exceding the limit
# Refitting, new chi2 = 0.266343839519
# chi2 = 2.29361230706 exceding the limit
# Refitting, new chi2 = 0.350657469936
# chi2 = 1.80890911522 exceding the limit
# Refitting, new chi2 = 0.546610985271
# chi2 = 1.62702530975 exceding the limit
# Refitting, new chi2 = 0.291845482621
# chi2 = 1.01966756232 exceding the limit
# Refitting, new chi2 = 0.368055884724
# chi2 = 1.84490565345 exceding the limit
# Refitting, new chi2 = 0.362004888968
# chi2 = 2.37887172319 exceding the limit
# Refitting, new chi2 = 0.525798261581
# chi2 = 3.16209133785 exceding the limit
# Refitting, new chi2 = 0.367231740468
# chi2 = 2.95933645543 exceding the limit
# Refitting, new chi2 = 0.295235865578
# chi2 = 3.20970766442 exceding the limit
# Refitting, new chi2 = 0.56741923613
# chi2 = 2.94118036254 exceding the limit
# Refitting, new chi2 = 0.230259943335
# chi2 = 2.65151735138 exceding the limit
# Refitting, new chi2 = 0.396171738559
# chi2 = 2.72728357589 exceding the limit
# Refitting, new chi2 = 0.399234960379
# PR.BPM85 processed with success 129/129 shots
# chi2 = 1.2874063454 exceding the limit
# Refitting, new chi2 = 0.364343075425
# chi2 = 1.13674410954 exceding the limit
# Refitting, new chi2 = 0.383166469831
# PR.BPM87 processed with success 129/129 shots
# chi2 = 1.08614541243 exceding the limit
# Refitting, new chi2 = 0.488166945692
# chi2 = 1.07550787494 exceding the limit
# Refitting, new chi2 = 0.305500937167
# chi2 = 1.10214046547 exceding the limit
# Refitting, new chi2 = 0.387835500888
# PR.BPM90 processed with success 129/129 shots
# chi2 = 1.25770012766 exceding the limit
# Refitting, new chi2 = 1.25770012767
# chi2 = 1.25770012767 exceding the limit
# Refitting, new chi2 = 1.25770012769
# chi2 = 1.25770012769 exceding the limit
# Refitting, new chi2 = 1.25770012775
# chi2 = 1.25770012775 exceding the limit
# Refitting, new chi2 = 12.8207252419
# chi2 = 12.8207252419 exceding the limit
# Refitting, new chi2 = 12.8207252419
# END phase reached
# fit do not converge on shot 6
# chi2 = 1.23980168384 exceding the limit
# Refitting, new chi2 = 1.2398016834
# chi2 = 1.2398016834 exceding the limit
# Refitting, new chi2 = 1.23980168377
# chi2 = 1.23980168377 exceding the limit
# Refitting, new chi2 = 1.23980168393
# chi2 = 1.23980168393 exceding the limit
# Refitting, new chi2 = 1.23980168446
# chi2 = 1.23980168446 exceding the limit
# Refitting, new chi2 = 2.58837472011
# END phase reached
# fit do not converge on shot 65
# chi2 = 1.02255108684 exceding the limit
# Refitting, new chi2 = 1.02255108704
# chi2 = 1.02255108704 exceding the limit
# Refitting, new chi2 = 1.02255108683
# chi2 = 1.02255108683 exceding the limit
# Refitting, new chi2 = 1.02255108699
# chi2 = 1.02255108699 exceding the limit
# Refitting, new chi2 = 1.02255108715
# chi2 = 1.02255108715 exceding the limit
# Refitting, new chi2 = 1.02255108703
# END phase reached
# fit do not converge on shot 102
# PR.BPM93 processed with success 126/129 shots
# PR.BPM95 processed with success 129/129 shots
# PR.BPM97 processed with success 129/129 shots
# Done.

# %%
# sanity check 
for k in range(34):
    plt.plot(myDataFrame['logical_PI_KFA45.K.value'].shift(shiftVal),osc_amplitude[:,k],'.')
    x1,x2,y1,y2 = plt.axis()
#     plt.axis((x1,x2,0,10))

# %%
# manual inspection
bpm_n = 0
plt.plot(myDataFrame['logical_PI_KFA45.K.value'].shift(shiftVal),osc_amplitude[:,bpm_n],'.')
x1,x2,y1,y2 = plt.axis()
# plt.axis((x1,x2,0,10))
print 'Beta_x at '+BPM_name[bpm_n]+': '+str(BPM_betax[bpm_n])
# Out:
# Beta_x at PR.BPM00: 12.038661

# %%
plt.plot(chi2[:,bpm_n],'.')

# %%
k = 0
m = 0 #bpm number

fig, ax  = plt.subplots(1,figsize=(12,6))
def f_to_fit(x, a, b, c, d):
    return a*np.sin(b*x + c) + d

xdata = np.linspace(0,30,30)
ydata = myDataFrame['PR_BPM.AcquisitionTrajectoryBBB.value.position'].apply(lambda x: 0.1*x[off+m,0:30]).values[k]
ax.plot(ydata,'-')

p0 = ([1.5*np.std(ydata), 0.41*pi, 0.1*pi, np.mean(ydata)])
ax.plot(f_to_fit(xdata, *p0), 'r')

bounds=([-np.inf, 0.01*pi, -pi, -np.inf],[np.inf,pi/2.,pi,np.inf])

p, cov = curve_fit(f_to_fit,xdata,ydata,bounds=bounds,p0=p0)

yfit = f_to_fit(xdata, *p)

ax.plot(yfit)

print(p)

print(np.sum((yfit - ydata)**2)/len(yfit))

print(chi2[k,m])
# Out:
# [ 3.43565017  1.32948228 -0.59076     2.1450949 ]
# 0.32829992179
# 0.328299921791

# %%
fig=plt.figure(figsize=(10, 8), dpi= 80, facecolor='w', edgecolor='k')
plt.imshow(osc_amplitude[:,:],
           cmap='hot',
           aspect='auto'
          )
plt.colorbar()
plt.xlabel('BPM number')
plt.ylabel('Shot number')
# Out:
# Text(0,0.5,u'Shot number')

# %% [markdown]
# ## 2. RMS orbit deviation 1st-2nd turn and 1st turn-1ms orbit

# %% [markdown]
# ### calculate the RMS orbit deviation
# Use difference between the first and second turn to evaluate the orbit deviation from the reference orbit, where
#
#
# $$\Delta x_\text{rms} =  \sqrt{\frac{1}{N} \sum_{i=1}^{N} (x_\text{turn2} - x_\text{turn1})^2 }$$
#
#
# excluding the BPM in the bump, that would dominate the estimator.
#
# Same for the deviation from the orbit
#
# $$\Delta x_\text{rms, orbit} = \sqrt{\frac{1}{N} \sum_{i=1}^{N} (x_\text{turn1} - x_\text{average_orbit_1ms})^2 }$$

# %%
# X plane
mySeries1 = myDataFrame['BPMx_turn1'].apply(lambda x: np.delete(x,17))
mySeries2 = myDataFrame['BPMx_turn2'].apply(lambda x: np.delete(x,17))
# bad BPM
mySeries1 = mySeries1.apply(lambda x: np.delete(x,36))
mySeries2 = mySeries2.apply(lambda x: np.delete(x,36))

# myOrbit = myDataFrame['Orbit_x'].apply(lambda x: np.delete(x,17))

myDataFrame['deltaX_2turns'] = signalRMSDifference(mySeries1,mySeries2,42) # BPM43 excluded
# myDataFrame['OrbitX_dev_RMS'] = signalRMSDifference(mySeries1,myOrbit,42) # BPM43 excluded

# Y plane
mySeries1 = myDataFrame['BPMy_turn1'].apply(lambda x: np.delete(x,17))
mySeries2 = myDataFrame['BPMy_turn2'].apply(lambda x: np.delete(x,17))
#bad BPM
mySeries1 = mySeries1.apply(lambda x: np.delete(x,36))
mySeries2 = mySeries2.apply(lambda x: np.delete(x,36))
myOrbit = myDataFrame['Orbit_y'].apply(lambda x: np.delete(x,17))

# myDataFrame['deltaY_2turns'] = signalRMSDifference(mySeries1,mySeries2,42) # BPM43 excluded
# myDataFrame['OrbitY_dev_RMS'] = signalRMSDifference(mySeries1,myOrbit,42) # BPM43 excluded

# %%
# DATA ONLY
# plt.plot(1e3*myDataFrame['logical_PI_KFA45.K.value'].shift(shiftVal),myDataFrame['deltaX_2turns'].values,'*',label='X plane')

# plt.xlabel('Kick (mrad)')
# plt.ylabel('RMS orbit deviation on first 2 turns(mm)')
# plt.title('First two turn RMS orbit difference')

# # plt.plot(1e3*myDataFrame['logical_PI_KFA45.K.value'].shift(shiftVal),myDataFrame['deltaY_2turns'].values,'*',label='Y plane')



# plt.legend(frameon=True)
# x1,x2,y1,y2 = plt.axis()
# # plt.axis((x1,x2,0,8))
# # plt.axvline(x=0.004381000000000, ymin=0, ymax = 8, linewidth=2, color='k')

# Comparison data + MADx 
kick_params = np.load('/eos/user/e/esenes/PS-injection-steering/MADx/6.21-6.185_kick_to_angle_params.npy')
xkick = np.array([ -0.3, 0., 0.3])
# off=1.5
plt.plot(xkick, kick_params[1] + np.abs(kick_params[0]*xkick),label='MADx')

plt.plot(1e3*(myDataFrame['logical_PI_KFA45.K.value'].shift(shiftVal) - rk),myDataFrame['deltaX_2turns'].values,'*',label='Y plane')

plt.xlabel('Kick (mrad)')
plt.ylabel('RMS orbit deviation on first 2 turns(mm)')
plt.title('First two turn RMS orbit difference')

plt.legend(frameon=True)
x1,x2,y1,y2 = plt.axis()
# plt.axis((x1,x2,0,8))
# plt.axvline(x=0.004381000000000, ymin=0, ymax = 8, linewidth=2, color='k')

# %%
plt.plot(myDataFrame['deltaX_2turns'].values, myDataFrame['WS_geom_emittance_x'],'*',label='X plane')

# %%
xrms12_mean = np.empty(len(ks_idx),dtype=float)
xrms12_std = np.empty(len(ks_idx),dtype=float)


for k in range(len(ks_idx)):
    if k==len(ks_idx)-1:
        xrms12_mean[k] = np.mean(myDataFrame['deltaX_2turns'].iloc[ks_idx[k]:]) # the last tranche to close the array
        xrms12_std[k] = np.std(myDataFrame['deltaX_2turns'].iloc[ks_idx[k]:]) # the last tranche to close the array
    else:
        xrms12_mean[k] = np.mean(myDataFrame['deltaX_2turns'].iloc[ks_idx[k]:ks_idx[k+1]]) 
        xrms12_std[k] = np.std(myDataFrame['deltaX_2turns'].iloc[ks_idx[k]:ks_idx[k+1]])

# %%
plt.errorbar(xrms12_mean, emix_mean, xerr=xrms12_std, yerr=emiy_std, fmt='o',label='emi_x')
plt.legend()

# %%
plt.plot(myDataFrame['deltaX_2turns'].values,myDataFrame['WS_geom_emittance_x'],'o')

# %% [markdown]
# # Methods comparison

# %% [markdown]
# ## 1) Single BPM method

# %%
bpm_n1 = 0
osc1 = osc_amplitude[:,bpm_n1]
print 'At '+BPM_name[bpm_n1]+' betax='+str(BPM_betax[bpm_n1])+' alphax='+str(BPM_alphax[bpm_n1])
print 'Expected value for the fit a='+str((1+BPM_alphax[bpm_n1]**2)/(2*BPM_betax[bpm_n1]))
bpm_n2 = 1
osc2 = osc_amplitude[:,bpm_n2]
print 'At '+BPM_name[bpm_n2]+' betax='+str(BPM_betax[bpm_n2])+' alphax='+str(BPM_alphax[bpm_n2])
print 'Expected value for the fit a='+str((1+BPM_alphax[bpm_n2]**2)/(2*BPM_betax[bpm_n2]))
# Out:
# At PR.BPM00 betax=12.038661 alphax=0.009937008495
# Expected value for the fit a=0.0415369593071
# At PR.BPM03 betax=22.10670041 alphax=0.01858203422
# Expected value for the fit a=0.0226253867254

# %%
from scipy.optimize import curve_fit

def f_to_fit(x, a, c):
    return a*(x )**2 + c

xdata = 1e-3*osc1
ydata = 1e-6*myDataFrame['WS_geom_emittance_x']

fig, ax = plt.subplots(1)
ax.plot(1e3*xdata, 1e6*ydata,'.',label='$\epsilon_x$') #factors are to adjust units in the plot

p, cov = curve_fit(f_to_fit,xdata,ydata)

xfit = np.linspace(np.min(xdata),np.max(xdata),200)
ax.plot(1e3*xfit, 1e6*f_to_fit(xfit, *p), 'r-', label='fit') #factors are to adjust units in the plot

#fit and plot fit
print 'Model function: a(x)^2 + c'
print 'Fit params: a=' + str(p[0]) + ' c= '+ str(p[1])


plt.xlabel('$\Delta x$ on 1 BPM (mm)')
plt.ylabel('Geometrical emittance (mm.mrad)')
plt.title(BPM_name[bpm_n1])

ax.text(0.55, 0.3, 'Fit function: $ax^2+c$:\n $a=$%.3f \n $c=$%.2E'%(p[0],p[1]),
        transform=ax.transAxes, fontsize=14,verticalalignment='top')


plt.legend(frameon=True)
print ' '
print 'At '+BPM_name[bpm_n1]+' betax='+str(BPM_betax[bpm_n1])+' alphax='+str(BPM_alphax[bpm_n1])
print 'Expected value for the fit a='+str((1+BPM_alphax[bpm_n1]**2)/(2*BPM_betax[bpm_n1]))


plt.legend(frameon=True)


x1,x2,y1,y2 = plt.axis()
# plt.axis((x1,x2,1,2.5))

fig.savefig('single_BPM185.eps', format='eps')
# Out:
# Model function: a(x)^2 + c
# Fit params: a=0.0195064559649 c= 7.50305997495e-07
#
# At PR.BPM00 betax=12.038661 alphax=0.009937008495
# Expected value for the fit a=0.0415369593071

# %%
from scipy.optimize import curve_fit

def f_to_fit(x, a, c):
    return a*(x )**2 + c

xdata = 1e-3*osc2
ydata = 1e-6*myDataFrame['WS_geom_emittance_x']

fig, ax = plt.subplots(1)
ax.plot(1e3*xdata, 1e6*ydata,'.',label='$\epsilon_x$') #factors are to adjust units in the plot

p, cov = curve_fit(f_to_fit,xdata,ydata)

xfit = np.linspace(np.min(xdata),np.max(xdata),200)
ax.plot(1e3*xfit, 1e6*f_to_fit(xfit, *p), 'r-', label='fit') #factors are to adjust units in the plot

#fit and plot fit
print 'Model function: a(x)^2 + c'
print 'Fit params: a=' + str(p[0]) + ' c= '+ str(p[1])


plt.xlabel('$\Delta_x$ on 1 BPM (mm)')
plt.ylabel('Geometrical emittance (mm.mrad)')
plt.title(BPM_name[bpm_n2])

ax.text(0.55, 0.3, 'Fit function: $ax^2+c$:\n $a=$%.3f \n $c=$%.2E'%(p[0],p[1]),
        transform=ax.transAxes, fontsize=14,verticalalignment='top')

x1,x2,y1,y2 = plt.axis()
# plt.axis((x1,x2,1.5,4.2))


plt.legend(frameon=True)
print ' '
print 'At '+BPM_name[bpm_n2]+' betax='+str(BPM_betax[bpm_n2])+' alphax='+str(BPM_alphax[bpm_n2])
print 'Expected value for the fit a='+str((1+BPM_alphax[bpm_n2]**2)/(2*BPM_betax[bpm_n2]))

plt.legend(frameon=True)


x1,x2,y1,y2 = plt.axis()
# plt.axis((x1,x2,1,1.9))

fig.savefig('single_BPM185.eps', format='eps')
# Out:
# Model function: a(x)^2 + c
# Fit params: a=0.00965222392862 c= 7.44837530347e-07
#
# At PR.BPM03 betax=22.10670041 alphax=0.01858203422
# Expected value for the fit a=0.0226253867254

# %% [markdown]
# ## 2) All BPM - single turn method

# %%
exp_a_allBPM = np.mean((1 + (BPM_alphax**2))/(2*BPM_betax))

# %%
from scipy.optimize import curve_fit

def f_to_fit(x, a, c):
    return a*(x)**2 + c

xdata = 1e-3*myDataFrame['deltaX_2turns']
ydata = 1e-6*myDataFrame['WS_geom_emittance_x']

fig, ax = plt.subplots(1)
ax.plot(1e3*xdata, 1e6*ydata,'.',label='$\epsilon_x$') #factors are to adjust units in the plot

p, cov = curve_fit(f_to_fit,xdata,ydata)
err = np.sqrt(np.diag(cov))

xfit = np.linspace(np.min(xdata),np.max(xdata),200)
ax.plot(1e3*xfit, 1e6*f_to_fit(xfit, *p), 'r-', label='fit') #factors are to adjust units in the plot

#fit and plot fit
print 'Model function: a(x)^2 + c'
print 'Fit params: \n a= ' + str(p[0]) + '+/-' + str(err[0]) + '\n c= '+ str(p[1]) + '+/-' + str(err[1])


plt.xlabel('$\Delta_{x,RMS}$ (mm)')
plt.ylabel('Geometrical emittance (mm.mrad)')
plt.title('First/second turn RMS difference')

ax.text(0.05, 0.95, 'Fit function: $ax^2+c$:\n $a=$%.3f \n $c=$%.2E'%(p[0],p[1]),
        transform=ax.transAxes, fontsize=14,verticalalignment='top')

x1,x2,y1,y2 = plt.axis()
# plt.axis((x1,x2,1.5,4.2))


plt.legend(frameon=True, bbox_to_anchor=(0.9,0.3))
print ' '
print 'Expected value for the fit a='+str(exp_a_allBPM)



x1,x2,y1,y2 = plt.axis()
# plt.axis((x1,x2,1,1.9))

fig.savefig('all_BPM185.eps', format='eps')
# Out:
# Model function: a(x)^2 + c
# Fit params:
#  a= 0.0174712306312+/-0.000806788254562
#  c= 6.9831436279e-07+/-7.9604912823e-09
#
# Expected value for the fit a=0.0282644589046

# %% [markdown]
# # Laslett tune shift calculation

# %%
myDataFrame['peakLineDensity'] = 0.6

# %%
# brightness and intensity
myDataFrame['WS_intensity'] = myDataFrame['Intensity'].apply(lambda x: x[80])
myDataFrame['Brightness'] = myDataFrame['WS_intensity']/(0.5*(myDataFrame['WS_emittance_x']+myDataFrame['WS_emittance_y']))

# %%
twiss_file_name = '/eos/user/e/esenes/AnalysisTools/Injection7_optics_Qx_0.21_Qy_0.23_cycled_timefalse.outx'

[deltaQx, deltaQy] = laslett_sc_PS(myDataFrame['peakLineDensity'], myDataFrame['deltaP_P_rms'],
              1e-6*myDataFrame['WS_emittance_x'], 1e-6*myDataFrame['WS_emittance_y'],
              1400, twiss_file_name)

myDataFrame['deltaQx'] = deltaQx
myDataFrame['deltaQy'] = deltaQy

# %%
fig, ax = plt.subplots(1)

# working point
Qx = 6.21
Qy = 6.18
plt.plot(Qx,Qy,'r.',markersize=10)

# tune diagram lines
ax.plot([5.8, 6.3],[5.8, 6.3],'k')
ax.plot([6, 6],[5.8, 6.3],'k')
ax.plot([5.8, 6.3],[6, 6],'k')
ax.plot([6.25, 6.25],[5.8, 6.3],'k')
ax.plot([5.8, 6.3],[6.25, 6.25],'k')
# options
plt.xlim([6.0, 6.26])
plt.ylim([5.9, 6.26])
# tune shifts
p1 = ax.scatter(Qx+myDataFrame['deltaQx'], Qy+myDataFrame['deltaQy'], c=myDataFrame['Brightness'], cmap=plt.cm.coolwarm)
clb = fig.colorbar(p1)
clb.set_label('Beam brightness')

# PSB point
[deltaQxPSB, deltaQyPSB] = laslett_sc_PS(0.6, 0.5e-3,
              1e-6*0.943, 1e-6*0.775,
              1400, twiss_file_name)
plt.plot(Qx+deltaQxPSB,Qy+deltaQyPSB,'*',markersize=15)


plt.show()

fig.savefig('BCMS_under_coupling_footprint.eps', format='eps')

# %%
myDataFrame['WS_emittance_y'].min()
# Out:
# 0.80106210163967961
