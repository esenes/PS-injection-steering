# %% [markdown]
# # Emittance measurement along the cycle with and without RF
#
# First of all let's see if the effect remains along the cycle

# %%
# %run /eos/project/l/liu/Toolbox/myToolbox.py
print '---'
# %run /eos/user/e/esenes/PS-analysis-tools/eTools.py
print '---'
sys.path.append('/eos/project/l/liu/Instrumentation/Scripts')
import metaclass
# Out:
# Version 0.03. This is the latest version.
# Please help me to improve it reporting bugs to guido.sterbini@cern.ch.
# Your platform is Linux-3.10.0-693.11.6.el7.x86_64-x86_64-with-redhat-6.9-Carbon
# Your folder is /eos/user/e/esenes/PS-injection-steering/Data analysis/2018.08.13
# Your IP is 172.17.0.27
# 2018-08-15 14:43:08
# ---
# Version 0.1
# Use at your own risk. Please report bugs to eugenio.senes@cern.ch
# Fork it at https://gitlab.cern.ch/esenes/PS-analysis-tools
# ---

# %%
sys.path.append('/eos/project/l/liu/Instrumentation/Scripts')
import metaclass

# %% [markdown]
# # User inputs

# %%
folderPath = '/eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/'

matlabVars = ['PR_BWS_65_H_ROT.Acquisition.value.projDataSet1', # Wirescanner 65
                'PR_BWS_65_H_ROT.Acquisition.value.projPositionSet1',
                'PR_BWS_65_H_ROT.Acquisition.value.acqTimeInCycleSet1',
                'PR_BWS_85_V_ROT.Acquisition.value.projDataSet1', # Wirescanner 85
                'PR_BWS_85_V_ROT.Acquisition.value.projPositionSet1',
                'PR_BWS_85_V_ROT.Acquisition.value.acqTimeInCycleSet1',
                'logical_PI_KFA45.K.value', # Kicker k parameter value (mrad)
                'PI_KFA45.AQN1.value',
                'PI_KFA45.CCV.value', 
                'PR_BPM.AcquisitionOrbit.value.position', # BPMs
                'PR_BPM.AcquisitionTrajectoryBBB.value.position',
                'PR_BCT_ST.Samples.value.samples',
                'PA_GSV10GLOBAL.Enable.enabled.value']

# %%
# let's start with the matlab data
files = sorted(glob.glob(folderPath+'/data/2018*.mat'))
print 'Found ' + str(len(files)) + ' data files'
print 'First: ' + files[0]
print 'End: ' + files[-1]
# Out:
# Found 141 data files
# First: /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//data/2018.08.13.12.11.16.151.mat
# End: /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//data/2018.08.13.13.37.23.207.mat

# %%
myDataFrame = myToolbox.fromMatlabToDataFrame(files,matlabVars,verbose=False)

# %%
myDataFrame['RF_on'] = myDataFrame['PA_GSV10GLOBAL.Enable.enabled.value']

# %% [markdown]
# # Data cleanup

# %%
myDataFrame = checkDuplicates(myDataFrame) # Drop double acquisitions from matlab
myDataFrame = checkBPMData(myDataFrame) # BPMs fault
# manual data drop
# myDataFrame = myDataFrame.drop(myDataFrame.loc['2017-11-14 17:58:45.100000'].name) # X wirescanner fault
# myDataFrame = myDataFrame.drop(myDataFrame.loc['2017-11-14 17:59:28.300000'].name) # non-phys emittance
# Out:
# Dropped 1 duplicate(s)
# ---
# BPM data ok
# ---

# %% [markdown]
# # Match the tomogram data

# %%
# directly copied from one of Guido's analyses
def extractProfile(fileName):
    '''Give me the input file (.dat) of the tomogram and I will give you 2 output:
        the deltaP_P and the the momentum distribution profile.
    ''' 

    print('/eos/project/l/liu/Instrumentation/tomography/runofflinetomo ' + fileName)
    a=os.system('/eos/project/l/liu/Instrumentation/tomography/runofflinetomo ' + fileName)
    
    convergence=np.loadtxt(fileName[0:-4] + '/d001.data')
    image=np.loadtxt(fileName[0:-4] + '/image001.data')
    with open(fileName[0:-4] + '/input_v2.dat','r') as stream: tomofileheader = stream.readlines()[:98]

    myInput={'PLSUSER': tomofileheader[0][0:-1],
            'NumberOfframes': np.int(tomofileheader[16][0:-1]),
            'B_T': np.double(tomofileheader[75][0:-1]),
            'Bdot_T_per_s': np.double(tomofileheader[77][0:-1]),
            'machineRadius_m': np.double(tomofileheader[79][0:-1]),
            'bendingRadius_m': np.double(tomofileheader[81][0:-1]),
            'particleMass_eV': np.double(tomofileheader[85][0:-1]),
            'h': np.int(np.double(tomofileheader[69][0:-1])),
            'ctime': np.int(tomofileheader[2]),
            'cycleStamp':np.int(tomofileheader[1]),                    # cyclestamp in unix time
            'pickupSensitivity':np.double(tomofileheader[97])          # pickup sensitivity
    }

    with open(fileName[0:-4] + '/plotinfo.data','r') as stream: tomofileheader = stream.readlines()

    myInput['profilecount']=np.int(str.split(tomofileheader[1])[2])
    myInput['profilelength']=np.int(str.split(tomofileheader[3])[2])

    myInput['dtbin']=np.double(str.split(tomofileheader[5])[2])
    myInput['dEbin']=np.double(str.split(tomofileheader[7])[2])
    myInput['xat0']=np.double(str.split(tomofileheader[11])[2])
    myInput['yat0']=np.double(str.split(tomofileheader[12])[2])
    myInput['eperimage']=np.double(str.split(tomofileheader[9])[2])

    mySpeedOfLight=299792458. #TODO
    myInput['momentum_eV']=myInput['B_T']*myInput['bendingRadius_m']/(10/mySpeedOfLight*1e8)*1.e9 #TODO
    myInput['totalEnergy_eV']=np.sqrt(myInput['momentum_eV']**2+myInput['particleMass_eV']**2)
    myInput['gamma']=myInput['totalEnergy_eV']/myInput['particleMass_eV']
    myInput['beta']=np.sqrt(1-1/myInput['gamma']**2)

    image=image*myInput['eperimage']/myInput['dtbin']/myInput['dEbin']

    halfProfileLength=myInput['profilelength']/2.

    Toffset= (myInput['xat0']-halfProfileLength)*myInput['dtbin']*1e9
    Eoffset= (myInput['yat0']-halfProfileLength)*myInput['dEbin']/1e6

    t=np.arange(-halfProfileLength,halfProfileLength)*myInput['dtbin']*1e9-Toffset
    E=np.arange(-halfProfileLength,halfProfileLength)*myInput['dEbin']/1e6-Eoffset


    deltaP_P= 1/myInput['beta']**2*E*1e6/myInput['totalEnergy_eV']
    myProfile=np.sum(np.reshape(image, [myInput['profilelength'], myInput['profilelength']]),0)
    myProfile=myProfile/np.trapz(myProfile,deltaP_P)
    myInput['deltaP_P']=deltaP_P;
    myInput['myProfile']=myProfile;
    myInput['E_MeV']=E
    myInput['t_ns']=t
    myInput['phaseSpace_e_per_eVs']=np.reshape(image, [myInput['profilelength'], myInput['profilelength']]);
    myProfileNormalized=myProfile/np.trapz(myProfile,deltaP_P)
    myMean=np.trapz(deltaP_P*myProfileNormalized,deltaP_P)
    myRMS=np.sqrt(np.trapz((deltaP_P-myMean)**2*myProfileNormalized,deltaP_P))
    myInput['deltaP_P_RMS']=myRMS
    return myInput

# %%
# new tomogram analysis
files_tomo=sorted(glob.glob(folderPath+'/tomo_data/*.dat'))

tomo_data = pnd.DataFrame()

for f in range(len(files_tomo)):
    try:
        tomo_d = extractProfile(files_tomo[f])
        tomo_d['Filename'] = files_tomo[f]
        if tomo_d is np.nan:
            pass
        else:
            tomo_data=tomo_data.append(tomo_d,ignore_index=True)
    except IOError:
        print '\nIOError\n'
# Out:
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_001.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_002.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_003.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_004.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_005.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_006.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_007.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_008.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_009.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_010.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_011.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_012.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_013.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_014.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_015.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_016.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_017.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_018.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_019.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_020.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_021.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_022.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_023.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_024.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_025.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_026.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_027.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_028.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_029.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_030.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_031.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_032.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_033.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_034.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_035.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_036.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_037.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_038.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_039.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_040.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_041.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_042.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_043.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_044.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_045.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_046.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_047.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_048.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_049.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_050.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_051.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_052.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_053.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_054.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_055.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_056.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_057.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_058.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_059.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_060.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_061.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_062.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_063.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_064.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_065.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_066.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_067.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_068.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_069.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_070.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_071.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_072.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_073.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_074.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_075.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_076.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_077.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_078.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_079.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_080.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_081.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_082.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_083.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_084.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_085.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_086.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_087.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_088.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_089.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_090.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_091.dat
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_092.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_093.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_094.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_095.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_096.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_097.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_098.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_099.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_100.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_101.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_102.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_103.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_104.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_105.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_106.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_107.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_108.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_109.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_110.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_111.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_112.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_113.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_114.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_115.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_116.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_117.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_118.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_119.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_120.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_121.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_122.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_123.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_124.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_125.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_126.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_127.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_128.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_129.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_130.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_131.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_132.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_133.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_134.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_135.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_136.dat
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_137.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_138.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_139.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_140.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_141.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_142.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_143.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_144.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_145.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_146.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_147.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_148.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_149.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_150.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_151.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_152.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_153.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_154.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_155.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_156.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_157.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_158.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_159.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_160.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_161.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_162.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_163.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_164.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_165.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_166.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_167.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_168.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_169.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_170.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_171.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_172.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_173.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_174.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_175.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_176.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_177.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_178.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_179.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_180.dat
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_181.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_182.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_183.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_184.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_185.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_186.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_187.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_188.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_189.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_190.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_191.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_192.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_193.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_194.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_195.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_196.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_197.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_198.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_199.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_200.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_201.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_202.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_203.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_204.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_205.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_206.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_207.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_208.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_209.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_210.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_211.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_212.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_213.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_214.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_215.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_216.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_217.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_218.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_219.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_220.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_221.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_222.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_223.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_224.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_225.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_226.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_227.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_228.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_229.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_230.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_231.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_232.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_233.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_234.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_235.dat
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_236.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_237.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_238.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_239.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_240.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_241.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle//tomo_data/C185_242.dat

# %%
timeTolerance = 18

# ---------- Vars initialisation
myDataFrame['tomoTimestamp']=np.nan
myDataFrame['tomoDelta']=np.nan
myDataFrame['tomoFilename']=np.str
myDataFrame['deltaP_P_rms']=np.nan
myDataFrame['peakLineDensity']=np.nan
myDataFrame['beta']=np.nan
myDataFrame['gamma']=np.nan
myDataFrame['deltaP_P']=[np.empty(0,dtype=float)]*len(myDataFrame)
myDataFrame['momentumProfile']=[np.empty(0,dtype=float)]*len(myDataFrame)


succ_count = 0
last_match = 0
# loop over the tomo_timestamps
for k in range(len(tomo_data)):
    tomo_local_cs = tomo_data['cycleStamp'].values[k]
    t = myToolbox.unixtime2datetime(tomo_local_cs)
    tomo_fname = tomo_data['Filename'].iloc[k]
    tomo_dpprms = tomo_data['deltaP_P_RMS'].iloc[k]
#     tomo_pkldens = tomo_data['peakLineDensity'].iloc[k]
    betar = tomo_data['beta'].iloc[k]
    gammar = tomo_data['gamma'].iloc[k]
    dpp_profil = tomo_data['deltaP_P'].iloc[k]
    p_profil = tomo_data['myProfile'].iloc[k]    


    # loop over the matlab data
    for x in range(len(myDataFrame)):
        c = myToolbox.unixtime2utcdatetime(myDataFrame['cycleStamp'].values[x]*1e-9)
        d = t-c
        d = d.total_seconds()

        if np.abs(d) <= timeTolerance and x > last_match: #avoid match the same tomogram to more matlab acquisition unintentionally
            myDataFrame['tomoTimestamp'].iloc[x] = tomo_local_cs
            myDataFrame['tomoFilename'].iloc[x] = tomo_fname
            myDataFrame['tomoDelta'].iloc[x] = d
            myDataFrame['deltaP_P_rms'].iloc[x]= tomo_dpprms
#             myDataFrame['peakLineDensity'].iloc[x]= tomo_pkldens
            myDataFrame['beta'].iloc[x]= betar
            myDataFrame['gamma'].iloc[x]= gammar
            myDataFrame['deltaP_P'].iloc[x]= dpp_profil
            myDataFrame['momentumProfile'].iloc[x]= p_profil


            succ_count += 1 #dummy counter
            
print str(succ_count) +"/"+ str(len(tomo_data)) +" are within the timeTolerance"
print 'length of dataframe is: '+ str(len(myDataFrame))
# Out:
# /cvmfs/sft.cern.ch/lcg/views/LCG_93/x86_64-slc6-gcc62-opt/lib/python2.7/site-packages/pandas/core/indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# 70/166 are within the timeTolerance
# length of dataframe is: 140

# %%
myDataFrame[['tomoFilename','deltaP_P_rms']].iloc[0:15]
# Out:
#                                                               tomoFilename  \
# 2018-08-13 12:11:12.700                                       <type 'str'>
# 2018-08-13 12:11:49.900  /eos/project/l/liu/PS/data/2017/MD2586_Injecti...
# 2018-08-13 12:13:04.300  /eos/project/l/liu/PS/data/2017/MD2586_Injecti...
# 2018-08-13 12:13:41.500  /eos/project/l/liu/PS/data/2017/MD2586_Injecti...
# 2018-08-13 12:14:18.700  /eos/project/l/liu/PS/data/2017/MD2586_Injecti...
# 2018-08-13 12:14:55.900  /eos/project/l/liu/PS/data/2017/MD2586_Injecti...
# 2018-08-13 12:15:33.100                                       <type 'str'>
# 2018-08-13 12:16:10.300                                       <type 'str'>
# 2018-08-13 12:16:47.500                                       <type 'str'>
# 2018-08-13 12:17:24.700                                       <type 'str'>
# 2018-08-13 12:18:01.900                                       <type 'str'>
# 2018-08-13 12:18:39.100  /eos/project/l/liu/PS/data/2017/MD2586_Injecti...
# 2018-08-13 12:19:16.300  /eos/project/l/liu/PS/data/2017/MD2586_Injecti...
# 2018-08-13 12:19:53.500  /eos/project/l/liu/PS/data/2017/MD2586_Injecti...
# 2018-08-13 12:20:30.700  /eos/project/l/liu/PS/data/2017/MD2586_Injecti...
#
#                          deltaP_P_rms
# 2018-08-13 12:11:12.700           NaN
# 2018-08-13 12:11:49.900      0.000861
# 2018-08-13 12:13:04.300      0.000874
# 2018-08-13 12:13:41.500      0.000865
# 2018-08-13 12:14:18.700      0.000863
# 2018-08-13 12:14:55.900      0.000856
# 2018-08-13 12:15:33.100           NaN
# 2018-08-13 12:16:10.300           NaN
# 2018-08-13 12:16:47.500           NaN
# 2018-08-13 12:17:24.700           NaN
# 2018-08-13 12:18:01.900           NaN
# 2018-08-13 12:18:39.100      0.000868
# 2018-08-13 12:19:16.300      0.000863
# 2018-08-13 12:19:53.500      0.000861
# 2018-08-13 12:20:30.700      0.000867

# %%
# new tomogram analysis --> RF OFF USE THE TOMOGRAMS OF THE PSB
files_tomo=sorted(glob.glob(folderPath+'tomo_data_PSB/*.dat'))

tomo_data = pnd.DataFrame()

for f in range(len(files_tomo)):
    try:
        tomo_d = extractProfile(files_tomo[f])
        tomo_d['Filename'] = files_tomo[f]
        if tomo_d is np.nan:
            pass
        else:
            tomo_data=tomo_data.append(tomo_d,ignore_index=True)
    except IOError:
        print '\nIOError\n'
# Out:
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_001.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_002.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_003.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_004.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_005.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_006.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_007.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_008.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_009.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_010.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_011.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_012.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_013.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_014.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_015.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_016.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_017.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_018.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_019.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_020.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_021.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_022.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_023.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_024.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_025.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_026.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_027.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_028.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_029.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_030.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_031.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_032.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_033.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_034.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_035.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_036.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_037.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_038.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_039.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_040.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_041.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_042.dat
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_043.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_044.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_045.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_046.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_047.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_048.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_049.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_050.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_051.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_052.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_053.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_054.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_055.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_056.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_057.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_058.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_059.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_060.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_061.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_062.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_063.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_064.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_065.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_066.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_067.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_068.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_069.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_070.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_071.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_072.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_073.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_074.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_075.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_076.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_077.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_078.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_079.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_080.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_081.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_082.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_083.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_084.dat
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_085.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_086.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_087.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_088.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_089.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_090.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_091.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_092.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_093.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_094.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_095.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_096.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_097.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_098.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_099.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_100.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_101.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_102.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_103.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_104.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_105.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_106.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_107.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_108.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_109.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_110.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_111.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_112.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_113.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_114.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_115.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_116.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_117.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_118.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_119.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_120.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_121.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_122.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_123.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_124.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_125.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_126.dat
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_127.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_128.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_129.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_130.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_131.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_132.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_133.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_134.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_135.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_136.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_137.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_138.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_139.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_140.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_141.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_142.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_143.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_144.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_145.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_146.dat
#
# IOError
#
# /eos/project/l/liu/Instrumentation/tomography/runofflinetomo /eos/project/l/liu/PS/data/2017/MD2586_InjectionEmittanceBlowup/2018.08.13/RF_on_off_along_cycle/tomo_data_PSB/autosave_147.dat
#
# IOError

# %%
timeTolerance = 18

# ---------- Vars initialisation
myDataFrame['tomoTimestamp']=np.nan
myDataFrame['tomoDelta']=np.nan
myDataFrame['tomoFilename']=np.str
myDataFrame['deltaP_P_rms']=np.nan
myDataFrame['peakLineDensity']=np.nan
myDataFrame['beta']=np.nan
myDataFrame['gamma']=np.nan
myDataFrame['deltaP_P']=[np.empty(0,dtype=float)]*len(myDataFrame)
myDataFrame['momentumProfile']=[np.empty(0,dtype=float)]*len(myDataFrame)


succ_count = 0
last_match = 0
# loop over the tomo_timestamps
for k in range(len(tomo_data)):
    tomo_local_cs = tomo_data['cycleStamp'].values[k]
    t = myToolbox.unixtime2datetime(tomo_local_cs)
    tomo_fname = tomo_data['Filename'].iloc[k]
    tomo_dpprms = tomo_data['deltaP_P_RMS'].iloc[k]
#     tomo_pkldens = tomo_data['peakLineDensity'].iloc[k]
    betar = tomo_data['beta'].iloc[k]
    gammar = tomo_data['gamma'].iloc[k]
    dpp_profil = tomo_data['deltaP_P'].iloc[k]
    p_profil = tomo_data['myProfile'].iloc[k]    


    # loop over the matlab data
    for x in range(len(myDataFrame)):
        c = myToolbox.unixtime2utcdatetime(myDataFrame['cycleStamp'].values[x]*1e-9)
        d = t-c
        d = d.total_seconds()

        if np.abs(d) <= timeTolerance and x > last_match: #avoid match the same tomogram to more matlab acquisition unintentionally
            myDataFrame['tomoTimestamp'].iloc[x] = tomo_local_cs
            myDataFrame['tomoFilename'].iloc[x] = tomo_fname
            myDataFrame['tomoDelta'].iloc[x] = d
            myDataFrame['deltaP_P_rms'].iloc[x]= tomo_dpprms
#             myDataFrame['peakLineDensity'].iloc[x]= tomo_pkldens
            myDataFrame['beta'].iloc[x]= betar
            myDataFrame['gamma'].iloc[x]= gammar
            myDataFrame['deltaP_P'].iloc[x]= dpp_profil
            myDataFrame['momentumProfile'].iloc[x]= p_profil


            succ_count += 1 #dummy counter
            
print str(succ_count) +"/"+ str(len(tomo_data)) +" are within the timeTolerance"
print 'length of dataframe is: '+ str(len(myDataFrame))

# %%
#stupid solution to the momentary problem with the PSB tomograms
myDataFrame['deltaP_P_rms'].loc[np.isnan(myDataFrame['tomoDelta'])] = 0.98e-3
myDataFrame['gamma'].loc[np.isnan(myDataFrame['tomoDelta'])] = myDataFrame['gamma'].iloc[1]
myDataFrame['beta'].loc[np.isnan(myDataFrame['tomoDelta'])] = myDataFrame['beta'].iloc[1]
myDataFrame['tomoDelta'].loc[np.isnan(myDataFrame['tomoDelta'])] = -1

# %%
# discard the elements without tomogram
discFlag = np.isnan(myDataFrame['tomoDelta'].values)
myDataFrame = myDataFrame.drop(myDataFrame.loc[discFlag].index)

# %% [markdown]
# # Save the imported data

# %%
myDataFrame.to_pickle('imported_data_2018.05.31_nominal_noRF.pkl')

# %%
# myDataFrame=pnd.read_pickle('imported_data_2018.05.17.pkl')

# %% [markdown]
# # Intensity

# %%
myDataFrame['Intensity'] = myDataFrame['PR_BCT_ST.Samples.value.samples']
myDataFrame['Losses'] = myDataFrame['Intensity'].apply(lambda x: 1-x[:][85]/np.max(x) )

# %%
plt.plot(np.linspace(0,len(myDataFrame)-1,len(myDataFrame)),myDataFrame['Losses'],'*')
x1,x2,y1,y2 = plt.axis()
# plt.axis((x1,x2,0,0.05))
plt.xlabel('Time ')
plt.ylabel('Losses')
# Out:
# Text(0,0.5,u'Losses')

# %%
for ll in range(10):
    plt.plot(myDataFrame['Intensity'].values[ll])
    
plt.axvline(x=90, ymin=0, ymax = 8, linewidth=2, color='k')
plt.xlabel('Cycle time (ms)')
plt.ylabel('BCT Intensity (*1e10 ppb)')
plt.title('10 shots intensity')
# Out:
# Text(0.5,1,u'10 shots intensity')

# %% [markdown]
# # Calculate wire scanner emittance
# ## X plane
# ### Traditional method

# %%
# Wirescanner sigma
#position data cleanup (sort, get unique values and the idxes) and conversion to mm
myDataFrame['BWS65_position'] = myDataFrame['PR_BWS_65_H_ROT.Acquisition.value.projPositionSet1'].apply(lambda x: np.unique(x, return_index=True)[0]*1e-3)
myDataFrame['BWS65_position_idx'] = myDataFrame['PR_BWS_65_H_ROT.Acquisition.value.projPositionSet1'].apply(lambda x: np.unique(x, return_index=True)[1])

#instantiate an array object for the result in the frame
myDataFrame['BWS65_data'] = myDataFrame['BWS65_position_idx'].apply(lambda x: np.empty(len(x)))
pos = np.arange(-50, 50, 0.05)

row, col = myDataFrame.shape

for r in xrange(row):
    myDataFrame['BWS65_data'].iloc[r] = np.interp(pos, myDataFrame['BWS65_position'].iloc[r], myDataFrame['PR_BWS_65_H_ROT.Acquisition.value.projDataSet1'].iloc[r][myDataFrame['BWS65_position_idx'].iloc[r]])  
    
#do the fit and get the sigma in mm
myDataFrame['WS_fit_results_x'] = myDataFrame['BWS65_data'].apply(lambda x: myToolbox.makeGaussianFit_5_parameters(pos,x))
myDataFrame['WS_sigma_x'] = myDataFrame['WS_fit_results_x'].apply(lambda x: x[0][-1])

# %%
# Emittance calculation
myDataFrame['WS_emittance_x'] = np.nan
myDataFrame['WS_geom_emittance_x'] = np.nan

for n in range(len(myDataFrame)):
#     myDataFrame['WS_emittance_x'].iloc[n] = normalised_emittance('65H',myDataFrame['WS_sigma_x'].values[n],dp=myDataFrame['deltaP_P_rms'].values[n])
    myDataFrame['WS_emittance_x'].iloc[n] = normalised_emittance('65H',myDataFrame['WS_sigma_x'].values[n],dp=0.83e-3)

    myDataFrame['WS_geom_emittance_x'].iloc[n] = myDataFrame['WS_emittance_x'].iloc[n]/(myDataFrame['beta'].iloc[n]*myDataFrame['gamma'].iloc[n])

# %%
# manual check
k=100

plt.plot(pos , myDataFrame['BWS65_data'].iloc[k])
plt.plot(pos, myToolbox.gaussian_5_parameters(pos,*myDataFrame['WS_fit_results_x'].iloc[k][0]),'r')

# %% [markdown]
# ## Y plane

# %%
# Wirescanner sigma
#position data cleanup (sort, get unique values and the idxes) and conversion to mm
myDataFrame['BWS85_position'] = myDataFrame['PR_BWS_85_V_ROT.Acquisition.value.projPositionSet1'].apply(lambda x: np.unique(x, return_index=True)[0]*1e-3)
myDataFrame['BWS85_position_idx'] = myDataFrame['PR_BWS_85_V_ROT.Acquisition.value.projPositionSet1'].apply(lambda x: np.unique(x, return_index=True)[1])

#instantiate an array object for the result in the frame
myDataFrame['BWS85_data'] = myDataFrame['BWS85_position_idx'].apply(lambda x: np.empty(len(x)))
pos = np.arange(-50, 50, 0.05)

row, col = myDataFrame.shape

for r in xrange(row):
    myDataFrame['BWS85_data'].iloc[r] = np.interp(pos, myDataFrame['BWS85_position'].iloc[r], myDataFrame['PR_BWS_85_V_ROT.Acquisition.value.projDataSet1'].iloc[r][myDataFrame['BWS85_position_idx'].iloc[r]])  

#do the fit and get the sigma in mm
myDataFrame['WS_fit_results_y'] = myDataFrame['BWS85_data'].apply(lambda x: myToolbox.makeGaussianFit_5_parameters(pos,x))
myDataFrame['WS_sigma_y'] = myDataFrame['WS_fit_results_y'].apply(lambda x: x[0][-1])
# Out:
# /cvmfs/sft.cern.ch/lcg/views/LCG_93/x86_64-slc6-gcc62-opt/lib/python2.7/site-packages/scipy/optimize/minpack.py:715: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %%
# Emittance calculation
myDataFrame['WS_emittance_y'] = myDataFrame['WS_sigma_y'].apply(lambda x: normalised_emittance('85V',x))

myDataFrame['WS_geom_emittance_y'] = np.nan
for n in range(len(myDataFrame)):
    myDataFrame['WS_geom_emittance_y'].iloc[n] = myDataFrame['WS_emittance_y'].iloc[n]/(myDataFrame['beta'].iloc[n]*myDataFrame['gamma'].iloc[n])

# %% [markdown]
# ## Calculate average emittance per measurement point

# %%
# find indexes of the shots at the same kick
ks = []
ks_idx = []
for k in range(len(myDataFrame)):
    if k == 0 :
        prevk = myDataFrame['PR_BWS_65_H_ROT.Acquisition.value.acqTimeInCycleSet1'].iloc[k]
        ks.append(prevk)
        ks_idx.append(k)
        continue
#     print(k)
    
    thisk = myDataFrame['PR_BWS_65_H_ROT.Acquisition.value.acqTimeInCycleSet1'].iloc[k]
    if (prevk-thisk) != 0:
#         print(thisk)
        ks.append(thisk)
        ks_idx.append(k)
    prevk = thisk

# %% [raw]
# # for checking ...
# for k in range(len(ks_idx)):
#     if k==len(ks_idx)-1:
#         print(myDataFrame['PR_BWS_65_H_ROT.Acquisition.value.acqTimeInCycleSet1'].iloc[ks_idx[k]:])
#     else:
#         print(myDataFrame['PR_BWS_65_H_ROT.Acquisition.value.acqTimeInCycleSet1'].iloc[ks_idx[k]:ks_idx[k+1]])

# %%
k_values = np.array((myDataFrame['PR_BWS_65_H_ROT.Acquisition.value.acqTimeInCycleSet1'].iloc[ks_idx]))

emix_mean = np.empty(len(ks_idx),dtype=float)
emiy_mean = np.empty(len(ks_idx),dtype=float)
emix_std = np.empty(len(ks_idx),dtype=float)
emiy_std = np.empty(len(ks_idx),dtype=float)


for k in range(len(ks_idx)):
    if k==len(ks_idx)-1:
        emix_mean[k] = np.mean(myDataFrame['WS_geom_emittance_x'].iloc[ks_idx[k]:]) # the last tranche to close the array
        emiy_mean[k] = np.mean(myDataFrame['WS_geom_emittance_y'].iloc[ks_idx[k]:]) # the last tranche to close the array
        emix_std[k] = np.std(myDataFrame['WS_geom_emittance_x'].iloc[ks_idx[k]:]) # the last tranche to close the array
        emiy_std[k] = np.std(myDataFrame['WS_geom_emittance_y'].iloc[ks_idx[k]:]) # the last tranche to close the array
    else:
        emix_mean[k] = np.mean(myDataFrame['WS_geom_emittance_x'].iloc[ks_idx[k]:ks_idx[k+1]]) 
        emiy_mean[k] = np.mean(myDataFrame['WS_geom_emittance_y'].iloc[ks_idx[k]:ks_idx[k+1]]) 
        emix_std[k] = np.std(myDataFrame['WS_geom_emittance_x'].iloc[ks_idx[k]:ks_idx[k+1]]) 
        emiy_std[k] = np.std(myDataFrame['WS_geom_emittance_y'].iloc[ks_idx[k]:ks_idx[k+1]])

# %%
fig, ax = plt.subplots(1,2,figsize=(10,5))

ax[0].errorbar(k_values, emix_mean, yerr=emix_std, fmt='o',label='emi_x')
ax[1].errorbar(k_values, emiy_mean, yerr=emiy_std, fmt='o',label='emi_y')

ax[0].set_xlabel('Cycle time (ms)')
ax[0].set_ylabel('Geom. emittance (mm.mrad)')
ax[1].set_xlabel('Cycle time (ms)')

# set axis to get rid of some bad shots
# x1,x2,y1,y2 = plt.axis()
# plt.axis((x1,x2,4,6.2))



ax[0].legend(frameon=True)
ax[1].legend(frameon=True)
fig.tight_layout()

fig.savefig('emix_y_along_cycle_geom.eps', format='eps',dpi=100)

# %%
plt.plot(myDataFrame['WS_emittance_x'].loc[myDataFrame['PA_GSV10GLOBAL.Enable.enabled.value']==1],'o',label='RF on')
plt.plot(myDataFrame['WS_emittance_x'].loc[myDataFrame['PA_GSV10GLOBAL.Enable.enabled.value']==0],'o',label='RF off')
plt.legend()

plt.ylim(1.5,2)
# Out:
# (1.5, 2)

# %%
k_values = np.array((myDataFrame['PR_BWS_65_H_ROT.Acquisition.value.acqTimeInCycleSet1'].iloc[ks_idx]))

emix_mean = np.empty(len(ks_idx),dtype=float)
emiy_mean = np.empty(len(ks_idx),dtype=float)
emix_std = np.empty(len(ks_idx),dtype=float)
emiy_std = np.empty(len(ks_idx),dtype=float)


for k in range(len(ks_idx)):
    if k==len(ks_idx)-1:
        emix_mean[k] = np.mean(myDataFrame['WS_emittance_x'].iloc[ks_idx[k]:]) # the last tranche to close the array
        emiy_mean[k] = np.mean(myDataFrame['WS_emittance_y'].iloc[ks_idx[k]:]) # the last tranche to close the array
        emix_std[k] = np.std(myDataFrame['WS_emittance_x'].iloc[ks_idx[k]:]) # the last tranche to close the array
        emiy_std[k] = np.std(myDataFrame['WS_emittance_y'].iloc[ks_idx[k]:]) # the last tranche to close the array
    else:
        emix_mean[k] = np.mean(myDataFrame['WS_emittance_x'].iloc[ks_idx[k]:ks_idx[k+1]]) 
        emiy_mean[k] = np.mean(myDataFrame['WS_emittance_y'].iloc[ks_idx[k]:ks_idx[k+1]]) 
        emix_std[k] = np.std(myDataFrame['WS_emittance_x'].iloc[ks_idx[k]:ks_idx[k+1]]) 
        emiy_std[k] = np.std(myDataFrame['WS_emittance_y'].iloc[ks_idx[k]:ks_idx[k+1]])

# %%
fig, ax = plt.subplots(1,2,figsize=(10,5))

ax[0].errorbar(k_values, emix_mean, yerr=emix_std, fmt='o',label='emi_x')
ax[1].errorbar(k_values, emiy_mean, yerr=emiy_std, fmt='o',label='emi_y')

ax[0].set_xlabel('Cycle time (ms)')
ax[0].set_ylabel('Norm. emittance (mm.mrad)')
ax[1].set_xlabel('Cycle time (ms)')

# set axis to get rid of some bad shots
x1,x2,y1,y2 = ax[0].axis()
# ax[0].axis((172,x2,y1,1.8))



ax[0].legend(frameon=True)
ax[1].legend(frameon=True)
fig.tight_layout()

fig.savefig('emix_y_along_cycle.eps', format='eps',dpi=100)

# %%
# crosscheck
plt.plot(np.arange(len(myDataFrame)),myDataFrame['deltaP_P_rms'],'.')

# %% [markdown]
# ## Emittance plot

# %%
fig, ax = plt.subplots(1)

ax.plot(myDataFrame['PR_BWS_65_H_ROT.Acquisition.value.acqTimeInCycleSet1'],myDataFrame['WS_emittance_x'],'.',label='$\epsilon_{x, norm}$')
plt.xlabel('Kick strength (mrad)')
plt.ylabel('Normalised emittance (mm.mrad)')
# plt.axvline(x=rk, ymin=0, ymax = 8, linewidth=2, color='k')
# set axis to get rid of some bad shots
x1,x2,y1,y2 = plt.axis()
# plt.axis((x1,x2,4,6.2))


# ax.plot(1e3*myDataFrame['logical_PI_KFA45.K.value'].shift(shiftVal),myDataFrame['WS_emittance_y'],'.',label='$\epsilon_{y, norm}$')

plt.legend(frameon=True)

fig.savefig('BCMS_under_coupling_emi_xy.eps', format='eps')

# %%
fig, ax = plt.subplots(1)

ax.plot(myDataFrame['PR_BWS_65_H_ROT.Acquisition.value.acqTimeInCycleSet1'],myDataFrame['WS_sigma_x'],'.',label='$\epsilon_{x, norm}$')
plt.xlabel('Kick strength (mrad)')
plt.ylabel('Normalised emittance (mm.mrad)')
# plt.axvline(x=rk, ymin=0, ymax = 8, linewidth=2, color='k')
# set axis to get rid of some bad shots
x1,x2,y1,y2 = plt.axis()
# plt.axis((x1,x2,4,6.2))


# ax.plot(1e3*myDataFrame['logical_PI_KFA45.K.value'].shift(shiftVal),myDataFrame['WS_emittance_y'],'.',label='$\epsilon_{y, norm}$')

plt.legend(frameon=True)

# fig.savefig('BCMS_under_coupling_emi_xy.eps', format='eps')

# %% [markdown]
# # Laslett tune shift calculation

# %%
myDataFrame['peakLineDensity'] = 0.6

# %%
# brightness and intensity
myDataFrame['WS_intensity'] = myDataFrame['Intensity'].apply(lambda x: x[80])
myDataFrame['Brightness'] = myDataFrame['WS_intensity']/(0.5*(myDataFrame['WS_emittance_x']+myDataFrame['WS_emittance_y']))

# %%
twiss_file_name = '/eos/user/e/esenes/AnalysisTools/Injection7_optics_Qx_0.21_Qy_0.23_cycled_timefalse.outx'

[deltaQx, deltaQy] = laslett_sc_PS(myDataFrame['peakLineDensity'], myDataFrame['deltaP_P_rms'],
              1e-6*myDataFrame['WS_emittance_x'], 1e-6*myDataFrame['WS_emittance_y'],
              1400, twiss_file_name)

myDataFrame['deltaQx'] = deltaQx
myDataFrame['deltaQy'] = deltaQy

# %%
fig, ax = plt.subplots(1)

# working point
Qx = 6.21
Qy = 6.19
plt.plot(Qx,Qy,'r.',markersize=10)

# tune diagram lines
ax.plot([5.8, 6.3],[5.8, 6.3],'k')
ax.plot([6, 6],[5.8, 6.3],'k')
ax.plot([5.8, 6.3],[6, 6],'k')
ax.plot([6.25, 6.25],[5.8, 6.3],'k')
ax.plot([5.8, 6.3],[6.25, 6.25],'k')
# options
plt.xlim([6.05, 6.26])
plt.ylim([5.98, 6.26])
# tune shifts
p1 = ax.scatter(Qx+myDataFrame['deltaQx'], Qy+myDataFrame['deltaQy'], c=myDataFrame['Brightness'], cmap=plt.cm.coolwarm)
clb = fig.colorbar(p1)
clb.set_label('Beam brightness')

# PSB point
[deltaQxPSB, deltaQyPSB] = laslett_sc_PS(0.6, 0.9e-3,
              1e-6*0.984, 1e-6*0.843,
              1400, twiss_file_name)
plt.plot(Qx+deltaQxPSB,Qy+deltaQyPSB,'*',markersize=15)


plt.show()

fig.savefig('BCMS_under_coupling_footprint.eps', format='eps')

# %% [markdown]
# ## Save the data

# %%
myDataFrame.to_pickle('analised_nominal_RF_off.pkl')

# %%
np.savetxt('emi_nominal_RFoff.txt',np.array([k_values, emix_mean, emix_std, emiy_mean, emiy_std]).T)
